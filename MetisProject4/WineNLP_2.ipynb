# %% [markdown]
# # Gensim style cleaning + flow

# %%
import pickle
with open('df_cleaned.pickle','rb') as read_file:
    df = pickle.load(read_file)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# NLP
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.probability import FreqDist
from gensim import corpora, models, similarities, matutils
from gensim.models import LsiModel
from gensim.models.coherencemodel import CoherenceModel

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction import text

# %% [markdown]
# # Clean text- remove punc, make lower case, remove numbers

# %%
# # Helper lambda fx to remove numbers and make lowercase
alphanumeric = lambda x: re.sub('\w*\d\w*', ' ', x)
punc_lower = lambda x: re.sub('[%s]' % re.escape(string.punctuation), ' ', x.lower())

# %%
df['description'] = df['description'].apply(alphanumeric).apply(punc_lower)

# %%
df['description'].sample(10)
# Out:
# 76770     this blend of    cabernet franc     malbec    ...
# 32685     aged only in stainless steel  this pretty soav...
# 23589     pure cabernet sauvignon from the yellow jacket...
# 9983      winemaker nick goldschmidt plies his trade mai...
# 60407     clean  crisp and fresh  which is enough to sat...
# 71827     this is pure malbec from the gamache vineyard ...
# 63012     bright pink in color  this is fresh and light ...
# 127693    it shows the classic aromas of alto adige sauv...
# 54308     the concerted impact of bergamot  grapefruit  ...
# 73942     dry in style and exuberantly fizzy  this fresh...
# Name: description, dtype: object

# %% [markdown]
# # Customize stop words
# - For now only adding Designation. Region + Varietal might provide info because of regional difs in tastes

# %%
# # Make columns lowercase so we can add them to stop words and they catch the already lowercase tokenized desc.
# df.winery = df.winery.str.lower()
# df.variety = df.variety.str.lower()
# df.region_1 = df.region_1.str.lower()
# df.region_2 = df.region_2.str.lower()
df.designation = df.designation.str.lower()

# # Need to make this a tuple because lists are mutable so can't add it to the set
# # Tuple is adding it as one element of all the wineries...not single words

# winery_list = set(df.winery.to_list())
# varietal_list = set(df.variety.to_list())
# region1_list = set(df.region_1.to_list())
# region2_list = set(df.region_2.to_list())
designation_list = set(df.designation.to_list())

# %%
designation_list = [str(i) for i in designation_list]

# %%
designation_list
# Out:
# ['nan',
#  'rhinefarm vineyard',
#  'dineen vineyard',
#  'fighting bulls',
#  'la grande cuvée',
#  'morgado da canita',
#  'el fanio',
#  'selleck vineyard',
#  "verna's vineyard",
#  'dolce bianco',
#  "chevalier d'anthelme",
#  'sceales vineyard',
#  'satrapezo',
#  'estate stonessence in the rocks vineyard',
#  'francis reserve white',
#  'monte da peceguina tinto',
#  'domaine de grand croix',
#  'domaine du manay',
#  'spellonu red',
#  'evolution big time',
#  'gilt',
#  'russian camp',
#  'the tri-centenary',
#  'vendimia seleccionada blanco',
#  'select',
#  "matthew's block",
#  'la piazza alta',
#  'louvau vineyard old vines',
#  'baranoff vineyard estate grown',
#  'made with organic grapes',
#  'quinta do encontro q do e',
#  'punto final mlb',
#  'les complices',
#  'les bartavelles',
#  'clifton vineyard',
#  'dauntless',
#  'rieflé bihl',
#  'audaz branco',
#  'scharzhoferger spätlese',
#  'arió extra dry',
#  'grapes organically grown',
#  'vigna della madonnina riserva',
#  'légende des toques',
#  'bishop creek vineyard',
#  'the cigar menzies vineyard',
#  'torcolato',
#  'cellar select',
#  'kiara private reserve',
#  'selezione antonio chiorri',
#  'the enchantress chardonnay french creek vineyard',
#  'kick ranch',
#  'bunker hill vineyard',
#  'vallocaia riserva',
#  'folly',
#  'sori paolin',
#  'korte ranch',
#  'lawrence vineyard le paon',
#  'tenute sirignano',
#  'estate grown proprietary red blend',
#  'santufili',
#  'annadel gap vineyard estate',
#  'bossona riserva',
#  'donna marzia',
#  'light madeira',
#  'vintage reserve',
#  'cuvée garance',
#  'morse vineyards',
#  "yesterday's song",
#  'pizzella',
#  'silverwood vineyard mountain grown',
#  'da vinci',
#  'tagus creek chardonnay-fernão pires',
#  "l'entente blanc",
#  'venus',
#  "cà de' rocchi",
#  'alwenn',
#  "old vine dina's vineyard",
#  'zinnkoepflé grand cru',
#  'de nit',
#  'pena do lobo',
#  'upland',
#  'château reserve',
#  'principia reserve',
#  "ellie's old vine",
#  "the fusilier proprietor's reserve",
#  'malterdinger bienenberg r gg erste lage',
#  'coyam los robles estate organic',
#  'sweet red table wine',
#  'torre muga',
#  'casa nocera',
#  'vigna giaia',
#  'sarmassa',
#  'sorangela',
#  'georgian valleys alazani valley',
#  'giersberger rosé',
#  'sergio extra dry',
#  'panesa fino',
#  'odyssea',
#  'inspiration vineyard magnolia series',
#  'artist series #7 red wine',
#  'margus margi',
#  "summation vintner's reserve",
#  'frederick brut',
#  "judge's reserve",
#  'levity',
#  'single vineyard plot: malva',
#  'salvestrin estate vineyard',
#  'stellar vineyard',
#  'reina ana gran reserva',
#  'viña rubican crianza',
#  'modello delle venezie',
#  'ensemble blanc',
#  'quinta do cachão',
#  'reserva la consulta vineyard',
#  'aah',
#  'cuvee trudi cuvee #10 rosé',
#  'tinaquaic vineyard',
#  'en chamberlin el jefe',
#  "cape winemakers guild daisy's turn shiraz-cabernet sauvignon-mourvèdre",
#  'marina espumante f° espumoso de fermentación natural',
#  'gran reserva edición limitada',
#  'goldrock ridge vineyard',
#  'bombshell red',
#  'marriage',
#  'merlot - cabernet sauvignon - shiraz',
#  'gravity',
#  'la chaudouillonne',
#  'javier asensio reserva',
#  'vale de cavalos',
#  'divinity late harvest',
#  'brave & maiden vineyard',
#  'the surrealist',
#  'windrow vineyards windrow red',
#  'sarah block swan song reserve',
#  'cutthroat red',
#  'tridentum brut rosé',
#  'quercetonda',
#  'spellbinding',
#  'no. 77',
#  'joven',
#  'les plantés',
#  'bella vigna vineyard',
#  'domaine la soufrandière',
#  'dolce',
#  'betsy vineyard',
#  'eichberger',
#  "doctor's vineyard",
#  'rioja bordón reserva',
#  'baron de chirel reserva',
#  'eroica ice wine',
#  'no 46',
#  'buzz',
#  'qm',
#  'dakishvili family vineyard',
#  'raso de larrainzar',
#  'gravelstone',
#  "primo's hill, estate grown",
#  'savagnin sous voile',
#  'viento vineyard',
#  'danseur',
#  'pato frio grand escolha',
#  'clasico',
#  'if six was nine reserve',
#  'block selection reserve block n.13',
#  'rive di colbertaldo vigneto giardino asciutto',
#  'morellone',
#  'neirane',
#  'cuvée paparazzi',
#  'fementado en barrica',
#  'mor',
#  'dalva reserva',
#  "on l'appelle",
#  'el preciado gran reserva',
#  "sant'anna",
#  'muros antigos escolha',
#  'les grès',
#  'la poja',
#  'regan vineyard orange wine',
#  'quattuor blanc de quatre blancs brut',
#  'goldtröpfchen spätlese',
#  'caleno oro',
#  'château tour blanche',
#  'villa prandone navicchio',
#  'terre originelle',
#  'nierstein trocken',
#  'i puri',
#  'lost vineyard',
#  'medium',
#  'corte c',
#  'domaine les hautes roches',
#  'champ salomon',
#  'ducceto',
#  'cuvée elena',
#  'villa marchesi',
#  'violet',
#  'jassarte',
#  'old vine reserva',
#  "garrett's vineyard estate",
#  'heringer estate vineyard',
#  'chenoweth ranch',
#  'chaos theory',
#  'quass',
#  'ole',
#  'michel forget premier cru brut',
#  'cuvée larsinos',
#  'dona isabel juliana',
#  'thomas schmitt private collection estate bottled spätlese',
#  'gold mine ranch',
#  'de sangre',
#  "colombelle l'original blanc",
#  'manu',
#  "ca' rosa",
#  'f/red',
#  'mistral red',
#  'miamba',
#  'memòro',
#  'exclusiv',
#  'amaro',
#  'puer apuliae',
#  'loibner loibenberg smaragd',
#  'le photographe',
#  'artz vineyard',
#  'mantsch',
#  '3rd generation',
#  'vitiano',
#  'alder ridge vineyard rosé',
#  'sagemoor',
#  'la fleur du barril',
#  'beautiful things',
#  "f'oz",
#  'outeiro',
#  'big tree block',
#  'big river ranch vineyard series',
#  'passagem late bottled vintage',
#  'eight barrels',
#  "icon d'azamor",
#  'bleu de mer',
#  'beet red',
#  'castello di nipozzano mormoreto',
#  'jacques sans souci',
#  'torre de menagem',
#  'il passo',
#  'cru perdu',
#  '3 puttonyos aszú',
#  'los lingues vineyard',
#  'felseneck walhausen spätlese grosse lage',
#  'ried hochberg',
#  'reserva selección de 198 barricas',
#  'malbec-merlot-cabernet sauvignon',
#  "jane's vineyard dijon clone 777",
#  'capitello',
#  'fleurs de savagnin',
#  'vigno old vines dry farmed',
#  "l'esprit de marius sangouard",
#  'orbus',
#  'der königsberg',
#  'orthogneiss sur lie',
#  'becquer',
#  'cicogna',
#  "rocche dell'annunziata riserva",
#  'montepulciano-sangiovese',
#  'grand clos',
#  'aristeo',
#  'overture',
#  'leras vineyard',
#  'réserve grand cru brut',
#  'huntington',
#  'riverbend vineyard tribute',
#  'les lavières premier cru',
#  'tsarine millésime brut',
#  'esprit de tablas blanc',
#  'sotirio',
#  'coccineous estate',
#  'three corner jack shiraz-cabernet-merlot',
#  'rolleri cuvee',
#  'clay wheels',
#  'herdade do peso colheita',
#  'white hawk',
#  'armando',
#  'sorhô',
#  'graacher himmelreich auslese goldkap',
#  'campo prognài',
#  'réserve des cleons',
#  'regaleali le rose',
#  'chenin blanc ice wine',
#  "vintner's cuvee xxi",
#  'dutton palms vineyard',
#  'jme selección',
#  'silvaspoons vineyard',
#  'goldberg alte reben',
#  'bergera pezzole',
#  'chatenay',
#  'domaine de reuilly les fossiles',
#  'königsberg',
#  'valle zangão',
#  'randolph reserve',
#  'avonlea',
#  'duemiladieci bianco metodo classico',
#  'solesce',
#  'ceuso',
#  'u cantu',
#  'vinho',
#  'opera 02',
#  'ockfener bockstein kabinett erste lage',
#  'cuvée st clément',
#  'strayts',
#  'pourriture noble',
#  "l'ange et luce",
#  'late harvest estate bottled',
#  'private selection branco',
#  'montornello',
#  '16 crows cuvée',
#  'ronco dei ciliegi',
#  'renner',
#  'cuvée du golfe de saint-tropez',
#  'cat amongst the pigeons nine lives',
#  'la fleur ribeyrolles',
#  'grande mélange',
#  "feuerheerd's 10-year-old tawny",
#  'tinta miúda',
#  'zinnkoepfle grand cru',
#  'va viña aljibes',
#  'caligo essència sweet white wine',
#  'riverside crossing',
#  'arbor creek vineyard',
#  'angimbé',
#  'lower east',
#  'casal garcia medium dry',
#  'bric du luv',
#  'julian madrid reserva',
#  'single organic vineyard',
#  'vigneto rafaèl',
#  'unánime',
#  'michaud vineyard',
#  'domaine de la garenne',
#  'diavolo',
#  'henoba',
#  'pago negralada',
#  'les hauts de sainte marie',
#  "la croix d'argon",
#  'bdp y',
#  'rock lake red',
#  'cobblestone vineyard reserve',
#  'laplace',
#  'damaris reserve',
#  'la garrigue',
#  'jayson',
#  'les sources',
#  'cuvee cassidy',
#  'innere bergen',
#  'ridge block single vineyard selection',
#  'brut carte noire',
#  'la noblaie rouge',
#  'clérotstein',
#  'cuvée des moines brut',
#  'marquês de marialva reserva',
#  'terzetto',
#  'lágrima',
#  'abbaye de morgeot premier cru',
#  'conde de vimioso extra bruto',
#  'le rosé de julie',
#  'ardal gran reserva selección especial',
#  'brique prestige',
#  'scharlachberg bingen auslese',
#  'upland vineyard gravière g.s.m.',
#  'omaggio a gino friedmann',
#  "poggio all'oro riserva",
#  't noble late harvest',
#  'clos prieur premier cru',
#  'célèbre',
#  'palestra branco',
#  'château grand chemin monplaisir',
#  'escaliers stairs',
#  'qp',
#  'le canon du marechal',
#  'purple by lagrezette',
#  'tolos',
#  'petit enira',
#  'herú',
#  'solano',
#  'don nelson gran reserva edición limitada',
#  'elerding six prong vineyard',
#  'fifty tons',
#  'rüdesheim berg roseneck trocken erstes gewächs',
#  'sofos the wise one moschofilero-chardonnay',
#  'château nozières',
#  'bench',
#  'les meyans elégance',
#  'les cerisiers vieilles vignes',
#  "koos-koos-kia colter's creek vineyard",
#  'exception',
#  'garnacha fusión',
#  'dauphiné',
#  'twelve barrels',
#  'la roggia',
#  'retsina of attica',
#  'dry creek mountain vineyard',
#  'klin',
#  'torrediluna',
#  "vigneti sant'helena",
#  'handverlesen',
#  'château argadens',
#  'tourmaline',
#  'amerique',
#  'porca de murça reserva',
#  'private reserve estate grown',
#  'pinot gris',
#  'les vignes de joanny',
#  'finca las palmas gran reserva',
#  'the y series limited release rosé',
#  'bon vallon',
#  'herdade do peso trinca bolotas',
#  'the big game',
#  'nonno rico oriolo riserva',
#  'epenots premier cru',
#  'unoaked estate',
#  'vivio vineyard',
#  'saitone vineyard olivet bench',
#  'calidonia',
#  'lopez ranch old vine',
#  'piesporter goldtröpfchen gg trocken',
#  'le chevalier de sterimberg',
#  'grand va',
#  'spirit of pinot noir',
#  'carreras ranch',
#  'estate reserve blend',
#  'sangioveto',
#  'fordbidden',
#  'charbonneau',
#  'studi fraedane',
#  'vinya les sorts',
#  'cuvée valérie',
#  'símbolo',
#  'a modern',
#  'quest by cauhapé',
#  'benuara',
#  'album lua cheia em vinhas velhas',
#  'bestué de otto bestué',
#  'opale demi-sec',
#  'cuvée caractères',
#  'martinet bru',
#  'domaine de saint pierre',
#  'follies',
#  "chatte d'avignon",
#  'quinta de pancas grande escolha',
#  'vin de paille',
#  'archè',
#  'lindes de san vincente',
#  'pickberry vineyard reserve',
#  'gaia made with organic grapes',
#  'món clàssic',
#  'francos reserva',
#  'mouton cadet réserve',
#  'viñedo no. 9',
#  'alphabet wines',
#  'san remo',
#  'aux clous premier cru',
#  'bramare zingaretti vineyard',
#  'barron-wahl vineyard',
#  'vigneto monachiara',
#  'assunto riserva',
#  'estate grand reserve',
#  'river junction',
#  'stillwater creek vineyard the wanted',
#  'clos de chênes premier cru',
#  'vers châne',
#  'santavenere',
#  'redemption zin',
#  'coeur de cuvée premier cru brut',
#  'yacochuya',
#  'syrah du soleil',
#  'estate malbec',
#  'francis coppola diamond collection gold label',
#  'mas elena merlot-cabernet franc-cabernet sauvignon',
#  'some poets',
#  'edna ranch vineyard',
#  'brut vintage',
#  '20 years old tawny',
#  'elevé en fût de chêne',
#  'empreinte rouge',
#  'grechons premier cru',
#  'ried renner',
#  'bernau block',
#  'grande reserve',
#  'lp brut',
#  'la casita',
#  'tavernello',
#  'monte carbonare',
#  'pioneer block 16 awatere',
#  'sauvignon blonde',
#  'ava',
#  'calpena extra dry',
#  'caiado tinto',
#  'cuvée hors classe les ménétrières',
#  'tradición',
#  "pauline's vineyard grenache",
#  'ozv',
#  'rued clone',
#  'sentimental blonde',
#  'lot 501',
#  'hedone rosso',
#  'meia lua',
#  "les vignes d'elisa",
#  'la viminière',
#  'domaine danielle laurent',
#  'luvisi vineyard',
#  'terrasses du bouscadel',
#  'rho',
#  'floodgate',
#  'angel hawk',
#  'est rosa',
#  'blauer schulen',
#  'virga',
#  'estate bottled vinho tinto',
#  'vigna lazzairasco',
#  'barco reale',
#  'garnacha & tempranillo',
#  'reserva oak barrel aged',
#  'les champonnets premier cru',
#  'bin 898 vintage select',
#  "river's red",
#  'heritage blanc vintage',
#  'soldati brut',
#  'wren song ice wine',
#  'bélingard',
#  'atisis cornell',
#  '35th anniversary reserve mailbox vineyard',
#  'fedora',
#  'polish hill',
#  'fantastique',
#  'rueslhof',
#  'valentino sweet red',
#  'legacy sundance vineyard',
#  'dona maria amantis reserva',
#  'lot 531',
#  'tenuta belguardo',
#  'santa caterina',
#  'michlovský',
#  'cabernet franc carmenère',
#  'glendale ranch',
#  "monte ca' bianca",
#  'romantique',
#  'stielle gran selezione',
#  'la côte rôtie',
#  'alary',
#  'ottimino vineyard',
#  'triomphe',
#  'pian piano',
#  'pouilly fume',
#  'lord botetourt limited',
#  'la belouse',
#  'les larmes de bacchus',
#  'plotzner',
#  'solesce red wine',
#  'gran reserva los quillayes vineyard',
#  'misciano - riserva',
#  'corpus',
#  'southview',
#  'gravel road',
#  'the hive',
#  'vigneto santa pia riserva',
#  'rosé di lulu',
#  "christopher's vineyard",
#  'colección vivanco parcelas de graciano',
#  'eight songs',
#  'tauro block boushey vineyard',
#  'conceito branco',
#  'ripasso',
#  'bridão reserva branco',
#  'climat les quarts',
#  'gilda',
#  'chehalem mountains',
#  'lunario',
#  'vv 47',
#  'staten family reserve',
#  'menzies the cigar',
#  'ma belle olsen vineyard',
#  'after the floods',
#  'terre de granit',
#  "anna's vineyard reserve",
#  'reserve bin',
#  'hein',
#  'blanco grande estate grown',
#  'vale de lobos',
#  'thérèse vineyards signature selection',
#  'conde valdemar gran reserva',
#  'allegre vineyard verona white',
#  'straits',
#  'gold top brut',
#  'grale',
#  'rouge e',
#  'rosé the benches at wallula',
#  'amalia',
#  'fathom',
#  'les blanchais',
#  'the true',
#  'la gena',
#  "monte dall'ora",
#  'urban ribera',
#  'munjebel rosso 9 cs',
#  '50 vendemmia riserva',
#  'les crots vieilles vignes',
#  'krupp vineyard',
#  'les garants',
#  'gavarini chiniera',
#  "crocodile's lair kaaimansgat",
#  'osezno',
#  'destiny ridge vineyards',
#  'domaine du pavillon clos des maréchaudes premier cru',
#  'white hills',
#  'brolo delle giare riserva',
#  'isolanuda bianco',
#  'subduction red',
#  'naoussa grande reserve',
#  'paradii',
#  'nectar de moncontour',
#  'rosengartl',
#  'augey',
#  'destination series estate grown',
#  'el pomar estate',
#  'conoscenti',
#  'beckstoffer dr. crane',
#  'campo inferi riserva',
#  'casillero del diablo reserva',
#  'la fleur lily semi-dry',
#  'exordium weinbau vineyard',
#  'premium limited edition',
#  'boushey vineyard liberté',
#  'vasthoudend',
#  'texas ranch vineyard reserve rows',
#  "river's edge casscles vineyards",
#  'vale de mata reserva',
#  'syzygy',
#  'musqué clone',
#  'santa nè',
#  'gravas del maipo',
#  'dominio de valdepusa',
#  "claire riley's pirate reserve",
#  'brut zéro sélection',
#  'la petite grace',
#  "mitsuko's vineyard",
#  'paz',
#  'mt. carmel vineyard',
#  'val saint grégoire',
#  'serrig schloss saarsteiner kabinett',
#  'cottà',
#  'block 4sb20',
#  "carter's mountain vineyard",
#  'stone vineyard',
#  'petit verdot',
#  'ehrhart hengst grand cru',
#  'satèn',
#  'franciscus messwein',
#  'blanc de blancs brut metodo classico',
#  'alegria vineyards axiom',
#  'bernier',
#  'three plumes',
#  'passopisciaro',
#  'graacher himmelreich spätlese',
#  'abandonado',
#  'bottaccia',
#  'fita azul passion rosé bruto',
#  'camp meeting ridge',
#  'ateo',
#  'bailli de provence',
#  'bell mountain vineyard',
#  'andreas',
#  'the climber',
#  '15 anos reserva',
#  'que sirah syrah destiny vineyards',
#  'plane vineyard pinot noir',
#  'riserva villa bonomi',
#  'loibner kreutles smaragd',
#  'the whitewing',
#  'réserve de famille',
#  'cru réserve',
#  'indo',
#  'estate cabernet franc',
#  'cuvée gabriella brut rosé',
#  'réserve du cléons sur lie',
#  'columbia valley',
#  'small-lot offering ghielmetti vineyard',
#  'pago dei fusi',
#  'thompson vineyard',
#  'claudia cuvee',
#  'poggio servale',
#  'songs of its own glenrose vineyard',
#  'murrae',
#  'griva vineyard late harvest',
#  'les gennievrières',
#  'celliere',
#  'old patch red lot# 43',
#  'califa selection estate',
#  'viva tu!',
#  'limited release estate grown',
#  'archer family vineyard',
#  'steen',
#  'beckstoffer to kalon vineyard north',
#  'monte rosso vineyard reserve',
#  'apreciado',
#  'le corti',
#  'special blend',
#  'kon-secco',
#  'alder creek vineyard',
#  'prince hill vineyard',
#  'vigna soccorso',
#  'terre di monteforte',
#  'gold coast vineyard',
#  '4 cépages',
#  'vinho branco',
#  'the crown jewels',
#  'te awa',
#  'cabernet family',
#  'tramontana',
#  'cavallo delle fate',
#  'koonunga hill',
#  "sharecropper's",
#  'east ridge block estate',
#  'aszú 3 puttonyos - 500 ml',
#  'tranquilo',
#  "l'instant",
#  'cuvée du py',
#  'tranquility cabernet sauvignon-tannat',
#  'paço dos cunhas de santar nature',
#  'weninger & gere',
#  'arcale',
#  'sondraia',
#  'small parcels favourite homestead',
#  'two creeks vineyards',
#  "l'aurore",
#  'focus',
#  'semi-sweet bianco',
#  'passetemps premier cru',
#  'el bon homme',
#  'de uco gran reserva',
#  'rasne',
#  'gaintus',
#  'fiordiligi',
#  'fifth edition',
#  'grand marrenon',
#  'sentinel northridge vineyard',
#  'gala 2 cabernet sauvignon-cabernet franc-merlot',
#  'serum',
#  'reserva selecció vinyes velles',
#  'le grascete',
#  'acinatico',
#  'yauquen',
#  'parenthesis',
#  'eremo san quirico',
#  'trueheart vineyard',
#  'firepeak vineyard',
#  'bona vita',
#  'preludio barrel select lot n°92',
#  'les sorcières',
#  'cyprès',
#  'winemakers blend',
#  'audace riserva',
#  'grosso metodo classico',
#  'les vieilles vignes de jacques vernay',
#  "governo all'uso toscano",
#  'clos bernarde rosé de 1ère taille',
#  'von unserm trocken',
#  'extra dry 47',
#  'breakneck creek',
#  'marquès de borba',
#  'ensemble',
#  'red hen ranch',
#  'colinas reserva',
#  'dueño de la luna',
#  'château de flore',
#  'esprit de sarrail',
#  'kapnias vineyard zygos',
#  '33 degrees north gracie hill vineyard, bdx',
#  'morine ranch',
#  'votre sante',
#  'célèbre rosé',
#  'year of the dragon',
#  'la viña de andres romeo',
#  'native goose',
#  'terre brûlée',
#  "winemaker's reserve estate",
#  'gran aracauno',
#  "marcy's vineyard",
#  'the essence of oregon',
#  'elusive queen',
#  'minuty prestige',
#  'vignes de 1940',
#  'cape winemakers guild hendrik biebouw',
#  'fiddlestix vineyard',
#  'alte reben pössnitzberg',
#  'roi clovis',
#  'orient',
#  'domaine de la boissoneuse',
#  'rosé troteligotte',
#  'thomas estate',
#  'bricco delle olive',
#  'cuvée authentique les clos grand cru',
#  'prinz salm spätlese',
#  'borgoforte',
#  'serrocielo',
#  'jubilo',
#  'the convict rocky ridge vineyard',
#  'the unknown',
#  'baba joon',
#  'amante',
#  'san stunet - s. stefanetto',
#  'doctrina perpetua',
#  'spritz and giggles brand cuvée',
#  'vigna le coste',
#  'hacienda lopez de haro',
#  'private reserve',
#  'bastion premier cru',
#  'cuvée inédite brut blanc de blancs',
#  '1865 single vineyard',
#  'finca vallobera javier san pedro',
#  'ried loiserberg',
#  'closerie des alisiers domaine fribourg',
#  'domaine le cotoyon',
#  'vallegrande',
#  'and why am i mr. pink? rosé of',
#  'gotico',
#  "doc's ranch vineyard",
#  'puro',
#  'grace, hope & joy',
#  "the d'arry's original",
#  'nymphéa prestige',
#  'la coudraye',
#  "la vigna dell'angelo",
#  'katherine corkrum',
#  'canis major',
#  'olho de mocho reserva',
#  'ried kittel',
#  'windfall vineyard',
#  '4 b',
#  'estelle sauvion',
#  'le chai des platanes',
#  'utopía roble',
#  'nik weis selection urban',
#  'toko vineyard el corte',
#  'terrasses de montmirail',
#  'ruby cuvée',
#  "palmes d'or vintage brut rosé",
#  'riserva campore',
#  'elegancé',
#  'finale',
#  'rsrv maison mumm cuvée 4+5 brut',
#  'olivet lane',
#  'teorama',
#  'bourgogne aligoté',
#  'mediterranean white',
#  'les hauts du tertre',
#  'réserve particulière brut',
#  "bricco dell'uccellone",
#  'diane de belgrave',
#  'il soller extra dry',
#  'maple vineyards',
#  'perenzo',
#  'campora',
#  'piedra negra gran',
#  'reserve quintet',
#  'bella collina vineyard stiletto',
#  'la pilar',
#  'bergterrassen federspiel',
#  'romantique harmony pilot ridge vineyard estate grown',
#  'equus tempranillo-cabernet sauvignon-syrah',
#  'heritage collection, six clones',
#  'sinfonía tannat-malbec-petit verdot',
#  'wente clone old vine',
#  'inigo montoya',
#  'allegro amabile',
#  'harman vineyard',
#  'salem vineyard',
#  'su reimond',
#  'abetina 2',
#  'parris estate reserve',
#  'seigneurs de monbazillac',
#  'private selection',
#  'herrenweg',
#  'maucho reserva',
#  'ranch reserve',
#  '1698',
#  'momentos',
#  '25th anniversary j cuvée',
#  'unionville home single vineyard estate bottled',
#  'cuvée 735 brut',
#  'egarade brut',
#  '9-3-5',
#  'balletto ranch',
#  'lieu-dit harth - cuvée carolin',
#  "l'eglantine",
#  'torre la moreira',
#  'the last ditch',
#  'daimon',
#  'unbound',
#  'vigneto bellavista',
#  'munda',
#  'traditionelle flaschengärung deutscher sekt extra trocken',
#  'five blocks wren and temperance hill',
#  'house wine',
#  'casual encounters',
#  'làvico',
#  'krimsekt white collection brut',
#  'particular',
#  'meandro do vale meão',
#  'rive di san floriano brut',
#  'premius bordeaux sauvignon',
#  'sélection jour de fruit',
#  'château de beaucastel',
#  'late harvest cluster select reserve',
#  'northern state',
#  'brut nature reserva de la fami',
#  'no. 239 dry',
#  'toyon farm',
#  'lucumone',
#  'lagunilla reserva',
#  'uvaggio storico dry',
#  'guarda rios branco',
#  'morrito estate grown',
#  'graševina',
#  'origine',
#  "l'aura de cambon",
#  'terres dorées grille-midi',
#  'langenloiser zweigelt',
#  'les porets saint-georges premier cru',
#  'stickleback red',
#  'pont brûlé',
#  'generation series cold chalk',
#  'viñedo chadwick',
#  'the bohan-dillon estate',
#  'luminoso',
#  'alatus blend',
#  'byron vineyard delta',
#  "sonnseit'n",
#  'into the fog',
#  'timeo',
#  'mimi',
#  'portugieser',
#  'rice-spivak vineyard',
#  'royal kabinett',
#  '10 anni riserva',
#  'pinot doonier',
#  'réserve du propriétaire',
#  'meritage 202',
#  "big john big john's vineyard vineyard select series",
#  'reserve - barrel fermented',
#  'big bad zin',
#  'lailum bianco',
#  'yasmin red kosher',
#  'michel lynch bio',
#  'commendator enrico',
#  'organic viticulture',
#  'three hills',
#  'château cheval noir',
#  'brv',
#  'elivette',
#  'moutier amet',
#  'feudo',
#  'tsarine premier cru brut',
#  'sixgill',
#  'unti vineyard old vine',
#  'sorante',
#  'ramnista single vineyard',
#  'vignarè',
#  'caligo',
#  'pioneer block 6 oh! block',
#  'sangre de toro de casta',
#  'falleri vineyard',
#  'le rosé premier cru brut',
#  'sorella',
#  'vino de parcela única',
#  'chaînes carteaux premier cru',
#  'bajancas',
#  'château de la deidière',
#  'rejoyce',
#  "portada winemaker's selection",
#  'eléve en fûts de chêne',
#  'the count',
#  'concepción',
#  'vita bella',
#  'dorn vineyard',
#  'black clover',
#  'calìo',
#  'tenuta valleselle aurum',
#  'valamasca',
#  'wineck-schlossberg grand cru',
#  'privat gran reserva brut nature',
#  "l'oie de périgord",
#  'fiori delle stelle ice wine block 1 vidal blanc-golden muscat-marechal foch',
#  'fina reserva ensamblaje sauvignon blanc-chardonnay-viognier',
#  'cape winemakers guild ghost corner cwg',
#  'cuvee rae lee avonlea',
#  'moelleux',
#  "the king's fury",
#  'erdener prälat auslese goldkapsel',
#  'elwetritsche',
#  'dona georgina',
#  'navigato family selection',
#  'in the hills estate foothills in the sun vineyard',
#  'yasmin red',
#  'terre del vulcano',
#  ...]

# %%
x = [d.split(' ') for d in designation_list]

# %%
des_lis = []
for i in x:
    des_lis.append(i)

# %%
des_lis
# Out:
# [['nan'],
#  ['rhinefarm', 'vineyard'],
#  ['dineen', 'vineyard'],
#  ['fighting', 'bulls'],
#  ['la', 'grande', 'cuvée'],
#  ['morgado', 'da', 'canita'],
#  ['el', 'fanio'],
#  ['selleck', 'vineyard'],
#  ["verna's", 'vineyard'],
#  ['dolce', 'bianco'],
#  ['chevalier', "d'anthelme"],
#  ['sceales', 'vineyard'],
#  ['satrapezo'],
#  ['estate', 'stonessence', 'in', 'the', 'rocks', 'vineyard'],
#  ['francis', 'reserve', 'white'],
#  ['monte', 'da', 'peceguina', 'tinto'],
#  ['domaine', 'de', 'grand', 'croix'],
#  ['domaine', 'du', 'manay'],
#  ['spellonu', 'red'],
#  ['evolution', 'big', 'time'],
#  ['gilt'],
#  ['russian', 'camp'],
#  ['the', 'tri-centenary'],
#  ['vendimia', 'seleccionada', 'blanco'],
#  ['select'],
#  ["matthew's", 'block'],
#  ['la', 'piazza', 'alta'],
#  ['louvau', 'vineyard', 'old', 'vines'],
#  ['baranoff', 'vineyard', 'estate', 'grown'],
#  ['made', 'with', 'organic', 'grapes'],
#  ['quinta', 'do', 'encontro', 'q', 'do', 'e'],
#  ['punto', 'final', 'mlb'],
#  ['les', 'complices'],
#  ['les', 'bartavelles'],
#  ['clifton', 'vineyard'],
#  ['dauntless'],
#  ['rieflé', 'bihl'],
#  ['audaz', 'branco'],
#  ['scharzhoferger', 'spätlese'],
#  ['arió', 'extra', 'dry'],
#  ['grapes', 'organically', 'grown'],
#  ['vigna', 'della', 'madonnina', 'riserva'],
#  ['légende', 'des', 'toques'],
#  ['bishop', 'creek', 'vineyard'],
#  ['the', 'cigar', 'menzies', 'vineyard'],
#  ['torcolato'],
#  ['cellar', 'select'],
#  ['kiara', 'private', 'reserve'],
#  ['selezione', 'antonio', 'chiorri'],
#  ['the', 'enchantress', 'chardonnay', 'french', 'creek', 'vineyard'],
#  ['kick', 'ranch'],
#  ['bunker', 'hill', 'vineyard'],
#  ['vallocaia', 'riserva'],
#  ['folly'],
#  ['sori', 'paolin'],
#  ['korte', 'ranch'],
#  ['lawrence', 'vineyard', 'le', 'paon'],
#  ['tenute', 'sirignano'],
#  ['estate', 'grown', 'proprietary', 'red', 'blend'],
#  ['santufili'],
#  ['annadel', 'gap', 'vineyard', 'estate'],
#  ['bossona', 'riserva'],
#  ['donna', 'marzia'],
#  ['light', 'madeira'],
#  ['vintage', 'reserve'],
#  ['cuvée', 'garance'],
#  ['morse', 'vineyards'],
#  ["yesterday's", 'song'],
#  ['pizzella'],
#  ['silverwood', 'vineyard', 'mountain', 'grown'],
#  ['da', 'vinci'],
#  ['tagus', 'creek', 'chardonnay-fernão', 'pires'],
#  ["l'entente", 'blanc'],
#  ['venus'],
#  ['cà', "de'", 'rocchi'],
#  ['alwenn'],
#  ['old', 'vine', "dina's", 'vineyard'],
#  ['zinnkoepflé', 'grand', 'cru'],
#  ['de', 'nit'],
#  ['pena', 'do', 'lobo'],
#  ['upland'],
#  ['château', 'reserve'],
#  ['principia', 'reserve'],
#  ["ellie's", 'old', 'vine'],
#  ['the', 'fusilier', "proprietor's", 'reserve'],
#  ['malterdinger', 'bienenberg', 'r', 'gg', 'erste', 'lage'],
#  ['coyam', 'los', 'robles', 'estate', 'organic'],
#  ['sweet', 'red', 'table', 'wine'],
#  ['torre', 'muga'],
#  ['casa', 'nocera'],
#  ['vigna', 'giaia'],
#  ['sarmassa'],
#  ['sorangela'],
#  ['georgian', 'valleys', 'alazani', 'valley'],
#  ['giersberger', 'rosé'],
#  ['sergio', 'extra', 'dry'],
#  ['panesa', 'fino'],
#  ['odyssea'],
#  ['inspiration', 'vineyard', 'magnolia', 'series'],
#  ['artist', 'series', '#7', 'red', 'wine'],
#  ['margus', 'margi'],
#  ['summation', "vintner's", 'reserve'],
#  ['frederick', 'brut'],
#  ["judge's", 'reserve'],
#  ['levity'],
#  ['single', 'vineyard', 'plot:', 'malva'],
#  ['salvestrin', 'estate', 'vineyard'],
#  ['stellar', 'vineyard'],
#  ['reina', 'ana', 'gran', 'reserva'],
#  ['viña', 'rubican', 'crianza'],
#  ['modello', 'delle', 'venezie'],
#  ['ensemble', 'blanc'],
#  ['quinta', 'do', 'cachão'],
#  ['reserva', 'la', 'consulta', 'vineyard'],
#  ['aah'],
#  ['cuvee', 'trudi', 'cuvee', '#10', 'rosé'],
#  ['tinaquaic', 'vineyard'],
#  ['en', 'chamberlin', 'el', 'jefe'],
#  ['cape',
#   'winemakers',
#   'guild',
#   "daisy's",
#   'turn',
#   'shiraz-cabernet',
#   'sauvignon-mourvèdre'],
#  ['marina', 'espumante', 'f°', 'espumoso', 'de', 'fermentación', 'natural'],
#  ['gran', 'reserva', 'edición', 'limitada'],
#  ['goldrock', 'ridge', 'vineyard'],
#  ['bombshell', 'red'],
#  ['marriage'],
#  ['merlot', '-', 'cabernet', 'sauvignon', '-', 'shiraz'],
#  ['gravity'],
#  ['la', 'chaudouillonne'],
#  ['javier', 'asensio', 'reserva'],
#  ['vale', 'de', 'cavalos'],
#  ['divinity', 'late', 'harvest'],
#  ['brave', '&', 'maiden', 'vineyard'],
#  ['the', 'surrealist'],
#  ['windrow', 'vineyards', 'windrow', 'red'],
#  ['sarah', 'block', 'swan', 'song', 'reserve'],
#  ['cutthroat', 'red'],
#  ['tridentum', 'brut', 'rosé'],
#  ['quercetonda'],
#  ['spellbinding'],
#  ['no.', '77'],
#  ['joven'],
#  ['les', 'plantés'],
#  ['bella', 'vigna', 'vineyard'],
#  ['domaine', 'la', 'soufrandière'],
#  ['dolce'],
#  ['betsy', 'vineyard'],
#  ['eichberger'],
#  ["doctor's", 'vineyard'],
#  ['rioja', 'bordón', 'reserva'],
#  ['baron', 'de', 'chirel', 'reserva'],
#  ['eroica', 'ice', 'wine'],
#  ['no', '46'],
#  ['buzz'],
#  ['qm'],
#  ['dakishvili', 'family', 'vineyard'],
#  ['raso', 'de', 'larrainzar'],
#  ['gravelstone'],
#  ["primo's", 'hill,', 'estate', 'grown'],
#  ['savagnin', 'sous', 'voile'],
#  ['viento', 'vineyard'],
#  ['danseur'],
#  ['pato', 'frio', 'grand', 'escolha'],
#  ['clasico'],
#  ['if', 'six', 'was', 'nine', 'reserve'],
#  ['block', 'selection', 'reserve', 'block', 'n.13'],
#  ['rive', 'di', 'colbertaldo', 'vigneto', 'giardino', 'asciutto'],
#  ['morellone'],
#  ['neirane'],
#  ['cuvée', 'paparazzi'],
#  ['fementado', 'en', 'barrica'],
#  ['mor'],
#  ['dalva', 'reserva'],
#  ['on', "l'appelle"],
#  ['el', 'preciado', 'gran', 'reserva'],
#  ["sant'anna"],
#  ['muros', 'antigos', 'escolha'],
#  ['les', 'grès'],
#  ['la', 'poja'],
#  ['regan', 'vineyard', 'orange', 'wine'],
#  ['quattuor', 'blanc', 'de', 'quatre', 'blancs', 'brut'],
#  ['goldtröpfchen', 'spätlese'],
#  ['caleno', 'oro'],
#  ['château', 'tour', 'blanche'],
#  ['villa', 'prandone', 'navicchio'],
#  ['terre', 'originelle'],
#  ['nierstein', 'trocken'],
#  ['i', 'puri'],
#  ['lost', 'vineyard'],
#  ['medium'],
#  ['corte', 'c'],
#  ['domaine', 'les', 'hautes', 'roches'],
#  ['champ', 'salomon'],
#  ['ducceto'],
#  ['cuvée', 'elena'],
#  ['villa', 'marchesi'],
#  ['violet'],
#  ['jassarte'],
#  ['old', 'vine', 'reserva'],
#  ["garrett's", 'vineyard', 'estate'],
#  ['heringer', 'estate', 'vineyard'],
#  ['chenoweth', 'ranch'],
#  ['chaos', 'theory'],
#  ['quass'],
#  ['ole'],
#  ['michel', 'forget', 'premier', 'cru', 'brut'],
#  ['cuvée', 'larsinos'],
#  ['dona', 'isabel', 'juliana'],
#  ['thomas',
#   'schmitt',
#   'private',
#   'collection',
#   'estate',
#   'bottled',
#   'spätlese'],
#  ['gold', 'mine', 'ranch'],
#  ['de', 'sangre'],
#  ['colombelle', "l'original", 'blanc'],
#  ['manu'],
#  ["ca'", 'rosa'],
#  ['f/red'],
#  ['mistral', 'red'],
#  ['miamba'],
#  ['memòro'],
#  ['exclusiv'],
#  ['amaro'],
#  ['puer', 'apuliae'],
#  ['loibner', 'loibenberg', 'smaragd'],
#  ['le', 'photographe'],
#  ['artz', 'vineyard'],
#  ['mantsch'],
#  ['3rd', 'generation'],
#  ['vitiano'],
#  ['alder', 'ridge', 'vineyard', 'rosé'],
#  ['sagemoor'],
#  ['la', 'fleur', 'du', 'barril'],
#  ['beautiful', 'things'],
#  ["f'oz"],
#  ['outeiro'],
#  ['big', 'tree', 'block'],
#  ['big', 'river', 'ranch', 'vineyard', 'series'],
#  ['passagem', 'late', 'bottled', 'vintage'],
#  ['eight', 'barrels'],
#  ['icon', "d'azamor"],
#  ['bleu', 'de', 'mer'],
#  ['beet', 'red'],
#  ['castello', 'di', 'nipozzano', 'mormoreto'],
#  ['jacques', 'sans', 'souci'],
#  ['torre', 'de', 'menagem'],
#  ['il', 'passo'],
#  ['cru', 'perdu'],
#  ['3', 'puttonyos', 'aszú'],
#  ['los', 'lingues', 'vineyard'],
#  ['felseneck', 'walhausen', 'spätlese', 'grosse', 'lage'],
#  ['ried', 'hochberg'],
#  ['reserva', 'selección', 'de', '198', 'barricas'],
#  ['malbec-merlot-cabernet', 'sauvignon'],
#  ["jane's", 'vineyard', 'dijon', 'clone', '777'],
#  ['capitello'],
#  ['fleurs', 'de', 'savagnin'],
#  ['vigno', 'old', 'vines', 'dry', 'farmed'],
#  ["l'esprit", 'de', 'marius', 'sangouard'],
#  ['orbus'],
#  ['der', 'königsberg'],
#  ['orthogneiss', 'sur', 'lie'],
#  ['becquer'],
#  ['cicogna'],
#  ['rocche', "dell'annunziata", 'riserva'],
#  ['montepulciano-sangiovese'],
#  ['grand', 'clos'],
#  ['aristeo'],
#  ['overture'],
#  ['leras', 'vineyard'],
#  ['réserve', 'grand', 'cru', 'brut'],
#  ['huntington'],
#  ['riverbend', 'vineyard', 'tribute'],
#  ['les', 'lavières', 'premier', 'cru'],
#  ['tsarine', 'millésime', 'brut'],
#  ['esprit', 'de', 'tablas', 'blanc'],
#  ['sotirio'],
#  ['coccineous', 'estate'],
#  ['three', 'corner', 'jack', 'shiraz-cabernet-merlot'],
#  ['rolleri', 'cuvee'],
#  ['clay', 'wheels'],
#  ['herdade', 'do', 'peso', 'colheita'],
#  ['white', 'hawk'],
#  ['armando'],
#  ['sorhô'],
#  ['graacher', 'himmelreich', 'auslese', 'goldkap'],
#  ['campo', 'prognài'],
#  ['réserve', 'des', 'cleons'],
#  ['regaleali', 'le', 'rose'],
#  ['chenin', 'blanc', 'ice', 'wine'],
#  ["vintner's", 'cuvee', 'xxi'],
#  ['dutton', 'palms', 'vineyard'],
#  ['jme', 'selección'],
#  ['silvaspoons', 'vineyard'],
#  ['goldberg', 'alte', 'reben'],
#  ['bergera', 'pezzole'],
#  ['chatenay'],
#  ['domaine', 'de', 'reuilly', 'les', 'fossiles'],
#  ['königsberg'],
#  ['valle', 'zangão'],
#  ['randolph', 'reserve'],
#  ['avonlea'],
#  ['duemiladieci', 'bianco', 'metodo', 'classico'],
#  ['solesce'],
#  ['ceuso'],
#  ['u', 'cantu'],
#  ['vinho'],
#  ['opera', '02'],
#  ['ockfener', 'bockstein', 'kabinett', 'erste', 'lage'],
#  ['cuvée', 'st', 'clément'],
#  ['strayts'],
#  ['pourriture', 'noble'],
#  ["l'ange", 'et', 'luce'],
#  ['late', 'harvest', 'estate', 'bottled'],
#  ['private', 'selection', 'branco'],
#  ['montornello'],
#  ['16', 'crows', 'cuvée'],
#  ['ronco', 'dei', 'ciliegi'],
#  ['renner'],
#  ['cuvée', 'du', 'golfe', 'de', 'saint-tropez'],
#  ['cat', 'amongst', 'the', 'pigeons', 'nine', 'lives'],
#  ['la', 'fleur', 'ribeyrolles'],
#  ['grande', 'mélange'],
#  ["feuerheerd's", '10-year-old', 'tawny'],
#  ['tinta', 'miúda'],
#  ['zinnkoepfle', 'grand', 'cru'],
#  ['va', 'viña', 'aljibes'],
#  ['caligo', 'essència', 'sweet', 'white', 'wine'],
#  ['riverside', 'crossing'],
#  ['arbor', 'creek', 'vineyard'],
#  ['angimbé'],
#  ['lower', 'east'],
#  ['casal', 'garcia', 'medium', 'dry'],
#  ['bric', 'du', 'luv'],
#  ['julian', 'madrid', 'reserva'],
#  ['single', 'organic', 'vineyard'],
#  ['vigneto', 'rafaèl'],
#  ['unánime'],
#  ['michaud', 'vineyard'],
#  ['domaine', 'de', 'la', 'garenne'],
#  ['diavolo'],
#  ['henoba'],
#  ['pago', 'negralada'],
#  ['les', 'hauts', 'de', 'sainte', 'marie'],
#  ['la', 'croix', "d'argon"],
#  ['bdp', 'y'],
#  ['rock', 'lake', 'red'],
#  ['cobblestone', 'vineyard', 'reserve'],
#  ['laplace'],
#  ['damaris', 'reserve'],
#  ['la', 'garrigue'],
#  ['jayson'],
#  ['les', 'sources'],
#  ['cuvee', 'cassidy'],
#  ['innere', 'bergen'],
#  ['ridge', 'block', 'single', 'vineyard', 'selection'],
#  ['brut', 'carte', 'noire'],
#  ['la', 'noblaie', 'rouge'],
#  ['clérotstein'],
#  ['cuvée', 'des', 'moines', 'brut'],
#  ['marquês', 'de', 'marialva', 'reserva'],
#  ['terzetto'],
#  ['lágrima'],
#  ['abbaye', 'de', 'morgeot', 'premier', 'cru'],
#  ['conde', 'de', 'vimioso', 'extra', 'bruto'],
#  ['le', 'rosé', 'de', 'julie'],
#  ['ardal', 'gran', 'reserva', 'selección', 'especial'],
#  ['brique', 'prestige'],
#  ['scharlachberg', 'bingen', 'auslese'],
#  ['upland', 'vineyard', 'gravière', 'g.s.m.'],
#  ['omaggio', 'a', 'gino', 'friedmann'],
#  ['poggio', "all'oro", 'riserva'],
#  ['t', 'noble', 'late', 'harvest'],
#  ['clos', 'prieur', 'premier', 'cru'],
#  ['célèbre'],
#  ['palestra', 'branco'],
#  ['château', 'grand', 'chemin', 'monplaisir'],
#  ['escaliers', 'stairs'],
#  ['qp'],
#  ['le', 'canon', 'du', 'marechal'],
#  ['purple', 'by', 'lagrezette'],
#  ['tolos'],
#  ['petit', 'enira'],
#  ['herú'],
#  ['solano'],
#  ['don', 'nelson', 'gran', 'reserva', 'edición', 'limitada'],
#  ['elerding', 'six', 'prong', 'vineyard'],
#  ['fifty', 'tons'],
#  ['rüdesheim', 'berg', 'roseneck', 'trocken', 'erstes', 'gewächs'],
#  ['sofos', 'the', 'wise', 'one', 'moschofilero-chardonnay'],
#  ['château', 'nozières'],
#  ['bench'],
#  ['les', 'meyans', 'elégance'],
#  ['les', 'cerisiers', 'vieilles', 'vignes'],
#  ['koos-koos-kia', "colter's", 'creek', 'vineyard'],
#  ['exception'],
#  ['garnacha', 'fusión'],
#  ['dauphiné'],
#  ['twelve', 'barrels'],
#  ['la', 'roggia'],
#  ['retsina', 'of', 'attica'],
#  ['dry', 'creek', 'mountain', 'vineyard'],
#  ['klin'],
#  ['torrediluna'],
#  ['vigneti', "sant'helena"],
#  ['handverlesen'],
#  ['château', 'argadens'],
#  ['tourmaline'],
#  ['amerique'],
#  ['porca', 'de', 'murça', 'reserva'],
#  ['private', 'reserve', 'estate', 'grown'],
#  ['pinot', 'gris'],
#  ['les', 'vignes', 'de', 'joanny'],
#  ['finca', 'las', 'palmas', 'gran', 'reserva'],
#  ['the', 'y', 'series', 'limited', 'release', 'rosé'],
#  ['bon', 'vallon'],
#  ['herdade', 'do', 'peso', 'trinca', 'bolotas'],
#  ['the', 'big', 'game'],
#  ['nonno', 'rico', 'oriolo', 'riserva'],
#  ['epenots', 'premier', 'cru'],
#  ['unoaked', 'estate'],
#  ['vivio', 'vineyard'],
#  ['saitone', 'vineyard', 'olivet', 'bench'],
#  ['calidonia'],
#  ['lopez', 'ranch', 'old', 'vine'],
#  ['piesporter', 'goldtröpfchen', 'gg', 'trocken'],
#  ['le', 'chevalier', 'de', 'sterimberg'],
#  ['grand', 'va'],
#  ['spirit', 'of', 'pinot', 'noir'],
#  ['carreras', 'ranch'],
#  ['estate', 'reserve', 'blend'],
#  ['sangioveto'],
#  ['fordbidden'],
#  ['charbonneau'],
#  ['studi', 'fraedane'],
#  ['vinya', 'les', 'sorts'],
#  ['cuvée', 'valérie'],
#  ['símbolo'],
#  ['a', 'modern'],
#  ['quest', 'by', 'cauhapé'],
#  ['benuara'],
#  ['album', 'lua', 'cheia', 'em', 'vinhas', 'velhas'],
#  ['bestué', 'de', 'otto', 'bestué'],
#  ['opale', 'demi-sec'],
#  ['cuvée', 'caractères'],
#  ['martinet', 'bru'],
#  ['domaine', 'de', 'saint', 'pierre'],
#  ['follies'],
#  ['chatte', "d'avignon"],
#  ['quinta', 'de', 'pancas', 'grande', 'escolha'],
#  ['vin', 'de', 'paille'],
#  ['archè'],
#  ['lindes', 'de', 'san', 'vincente'],
#  ['pickberry', 'vineyard', 'reserve'],
#  ['gaia', 'made', 'with', 'organic', 'grapes'],
#  ['món', 'clàssic'],
#  ['francos', 'reserva'],
#  ['mouton', 'cadet', 'réserve'],
#  ['viñedo', 'no.', '9'],
#  ['alphabet', 'wines'],
#  ['san', 'remo'],
#  ['aux', 'clous', 'premier', 'cru'],
#  ['bramare', 'zingaretti', 'vineyard'],
#  ['barron-wahl', 'vineyard'],
#  ['vigneto', 'monachiara'],
#  ['assunto', 'riserva'],
#  ['estate', 'grand', 'reserve'],
#  ['river', 'junction'],
#  ['stillwater', 'creek', 'vineyard', 'the', 'wanted'],
#  ['clos', 'de', 'chênes', 'premier', 'cru'],
#  ['vers', 'châne'],
#  ['santavenere'],
#  ['redemption', 'zin'],
#  ['coeur', 'de', 'cuvée', 'premier', 'cru', 'brut'],
#  ['yacochuya'],
#  ['syrah', 'du', 'soleil'],
#  ['estate', 'malbec'],
#  ['francis', 'coppola', 'diamond', 'collection', 'gold', 'label'],
#  ['mas', 'elena', 'merlot-cabernet', 'franc-cabernet', 'sauvignon'],
#  ['some', 'poets'],
#  ['edna', 'ranch', 'vineyard'],
#  ['brut', 'vintage'],
#  ['20', 'years', 'old', 'tawny'],
#  ['elevé', 'en', 'fût', 'de', 'chêne'],
#  ['empreinte', 'rouge'],
#  ['grechons', 'premier', 'cru'],
#  ['ried', 'renner'],
#  ['bernau', 'block'],
#  ['grande', 'reserve'],
#  ['lp', 'brut'],
#  ['la', 'casita'],
#  ['tavernello'],
#  ['monte', 'carbonare'],
#  ['pioneer', 'block', '16', 'awatere'],
#  ['sauvignon', 'blonde'],
#  ['ava'],
#  ['calpena', 'extra', 'dry'],
#  ['caiado', 'tinto'],
#  ['cuvée', 'hors', 'classe', 'les', 'ménétrières'],
#  ['tradición'],
#  ["pauline's", 'vineyard', 'grenache'],
#  ['ozv'],
#  ['rued', 'clone'],
#  ['sentimental', 'blonde'],
#  ['lot', '501'],
#  ['hedone', 'rosso'],
#  ['meia', 'lua'],
#  ['les', 'vignes', "d'elisa"],
#  ['la', 'viminière'],
#  ['domaine', 'danielle', 'laurent'],
#  ['luvisi', 'vineyard'],
#  ['terrasses', 'du', 'bouscadel'],
#  ['rho'],
#  ['floodgate'],
#  ['angel', 'hawk'],
#  ['est', 'rosa'],
#  ['blauer', 'schulen'],
#  ['virga'],
#  ['estate', 'bottled', 'vinho', 'tinto'],
#  ['vigna', 'lazzairasco'],
#  ['barco', 'reale'],
#  ['garnacha', '&', 'tempranillo'],
#  ['reserva', 'oak', 'barrel', 'aged'],
#  ['les', 'champonnets', 'premier', 'cru'],
#  ['bin', '898', 'vintage', 'select'],
#  ["river's", 'red'],
#  ['heritage', 'blanc', 'vintage'],
#  ['soldati', 'brut'],
#  ['wren', 'song', 'ice', 'wine'],
#  ['bélingard'],
#  ['atisis', 'cornell'],
#  ['35th', 'anniversary', 'reserve', 'mailbox', 'vineyard'],
#  ['fedora'],
#  ['polish', 'hill'],
#  ['fantastique'],
#  ['rueslhof'],
#  ['valentino', 'sweet', 'red'],
#  ['legacy', 'sundance', 'vineyard'],
#  ['dona', 'maria', 'amantis', 'reserva'],
#  ['lot', '531'],
#  ['tenuta', 'belguardo'],
#  ['santa', 'caterina'],
#  ['michlovský'],
#  ['cabernet', 'franc', 'carmenère'],
#  ['glendale', 'ranch'],
#  ['monte', "ca'", 'bianca'],
#  ['romantique'],
#  ['stielle', 'gran', 'selezione'],
#  ['la', 'côte', 'rôtie'],
#  ['alary'],
#  ['ottimino', 'vineyard'],
#  ['triomphe'],
#  ['pian', 'piano'],
#  ['pouilly', 'fume'],
#  ['lord', 'botetourt', 'limited'],
#  ['la', 'belouse'],
#  ['les', 'larmes', 'de', 'bacchus'],
#  ['plotzner'],
#  ['solesce', 'red', 'wine'],
#  ['gran', 'reserva', 'los', 'quillayes', 'vineyard'],
#  ['misciano', '-', 'riserva'],
#  ['corpus'],
#  ['southview'],
#  ['gravel', 'road'],
#  ['the', 'hive'],
#  ['vigneto', 'santa', 'pia', 'riserva'],
#  ['rosé', 'di', 'lulu'],
#  ["christopher's", 'vineyard'],
#  ['colección', 'vivanco', 'parcelas', 'de', 'graciano'],
#  ['eight', 'songs'],
#  ['tauro', 'block', 'boushey', 'vineyard'],
#  ['conceito', 'branco'],
#  ['ripasso'],
#  ['bridão', 'reserva', 'branco'],
#  ['climat', 'les', 'quarts'],
#  ['gilda'],
#  ['chehalem', 'mountains'],
#  ['lunario'],
#  ['vv', '47'],
#  ['staten', 'family', 'reserve'],
#  ['menzies', 'the', 'cigar'],
#  ['ma', 'belle', 'olsen', 'vineyard'],
#  ['after', 'the', 'floods'],
#  ['terre', 'de', 'granit'],
#  ["anna's", 'vineyard', 'reserve'],
#  ['reserve', 'bin'],
#  ['hein'],
#  ['blanco', 'grande', 'estate', 'grown'],
#  ['vale', 'de', 'lobos'],
#  ['thérèse', 'vineyards', 'signature', 'selection'],
#  ['conde', 'valdemar', 'gran', 'reserva'],
#  ['allegre', 'vineyard', 'verona', 'white'],
#  ['straits'],
#  ['gold', 'top', 'brut'],
#  ['grale'],
#  ['rouge', 'e'],
#  ['rosé', 'the', 'benches', 'at', 'wallula'],
#  ['amalia'],
#  ['fathom'],
#  ['les', 'blanchais'],
#  ['the', 'true'],
#  ['la', 'gena'],
#  ['monte', "dall'ora"],
#  ['urban', 'ribera'],
#  ['munjebel', 'rosso', '9', 'cs'],
#  ['50', 'vendemmia', 'riserva'],
#  ['les', 'crots', 'vieilles', 'vignes'],
#  ['krupp', 'vineyard'],
#  ['les', 'garants'],
#  ['gavarini', 'chiniera'],
#  ["crocodile's", 'lair', 'kaaimansgat'],
#  ['osezno'],
#  ['destiny', 'ridge', 'vineyards'],
#  ['domaine', 'du', 'pavillon', 'clos', 'des', 'maréchaudes', 'premier', 'cru'],
#  ['white', 'hills'],
#  ['brolo', 'delle', 'giare', 'riserva'],
#  ['isolanuda', 'bianco'],
#  ['subduction', 'red'],
#  ['naoussa', 'grande', 'reserve'],
#  ['paradii'],
#  ['nectar', 'de', 'moncontour'],
#  ['rosengartl'],
#  ['augey'],
#  ['destination', 'series', 'estate', 'grown'],
#  ['el', 'pomar', 'estate'],
#  ['conoscenti'],
#  ['beckstoffer', 'dr.', 'crane'],
#  ['campo', 'inferi', 'riserva'],
#  ['casillero', 'del', 'diablo', 'reserva'],
#  ['la', 'fleur', 'lily', 'semi-dry'],
#  ['exordium', 'weinbau', 'vineyard'],
#  ['premium', 'limited', 'edition'],
#  ['boushey', 'vineyard', 'liberté'],
#  ['vasthoudend'],
#  ['texas', 'ranch', 'vineyard', 'reserve', 'rows'],
#  ["river's", 'edge', 'casscles', 'vineyards'],
#  ['vale', 'de', 'mata', 'reserva'],
#  ['syzygy'],
#  ['musqué', 'clone'],
#  ['santa', 'nè'],
#  ['gravas', 'del', 'maipo'],
#  ['dominio', 'de', 'valdepusa'],
#  ['claire', "riley's", 'pirate', 'reserve'],
#  ['brut', 'zéro', 'sélection'],
#  ['la', 'petite', 'grace'],
#  ["mitsuko's", 'vineyard'],
#  ['paz'],
#  ['mt.', 'carmel', 'vineyard'],
#  ['val', 'saint', 'grégoire'],
#  ['serrig', 'schloss', 'saarsteiner', 'kabinett'],
#  ['cottà'],
#  ['block', '4sb20'],
#  ["carter's", 'mountain', 'vineyard'],
#  ['stone', 'vineyard'],
#  ['petit', 'verdot'],
#  ['ehrhart', 'hengst', 'grand', 'cru'],
#  ['satèn'],
#  ['franciscus', 'messwein'],
#  ['blanc', 'de', 'blancs', 'brut', 'metodo', 'classico'],
#  ['alegria', 'vineyards', 'axiom'],
#  ['bernier'],
#  ['three', 'plumes'],
#  ['passopisciaro'],
#  ['graacher', 'himmelreich', 'spätlese'],
#  ['abandonado'],
#  ['bottaccia'],
#  ['fita', 'azul', 'passion', 'rosé', 'bruto'],
#  ['camp', 'meeting', 'ridge'],
#  ['ateo'],
#  ['bailli', 'de', 'provence'],
#  ['bell', 'mountain', 'vineyard'],
#  ['andreas'],
#  ['the', 'climber'],
#  ['15', 'anos', 'reserva'],
#  ['que', 'sirah', 'syrah', 'destiny', 'vineyards'],
#  ['plane', 'vineyard', 'pinot', 'noir'],
#  ['riserva', 'villa', 'bonomi'],
#  ['loibner', 'kreutles', 'smaragd'],
#  ['the', 'whitewing'],
#  ['réserve', 'de', 'famille'],
#  ['cru', 'réserve'],
#  ['indo'],
#  ['estate', 'cabernet', 'franc'],
#  ['cuvée', 'gabriella', 'brut', 'rosé'],
#  ['réserve', 'du', 'cléons', 'sur', 'lie'],
#  ['columbia', 'valley'],
#  ['small-lot', 'offering', 'ghielmetti', 'vineyard'],
#  ['pago', 'dei', 'fusi'],
#  ['thompson', 'vineyard'],
#  ['claudia', 'cuvee'],
#  ['poggio', 'servale'],
#  ['songs', 'of', 'its', 'own', 'glenrose', 'vineyard'],
#  ['murrae'],
#  ['griva', 'vineyard', 'late', 'harvest'],
#  ['les', 'gennievrières'],
#  ['celliere'],
#  ['old', 'patch', 'red', 'lot#', '43'],
#  ['califa', 'selection', 'estate'],
#  ['viva', 'tu!'],
#  ['limited', 'release', 'estate', 'grown'],
#  ['archer', 'family', 'vineyard'],
#  ['steen'],
#  ['beckstoffer', 'to', 'kalon', 'vineyard', 'north'],
#  ['monte', 'rosso', 'vineyard', 'reserve'],
#  ['apreciado'],
#  ['le', 'corti'],
#  ['special', 'blend'],
#  ['kon-secco'],
#  ['alder', 'creek', 'vineyard'],
#  ['prince', 'hill', 'vineyard'],
#  ['vigna', 'soccorso'],
#  ['terre', 'di', 'monteforte'],
#  ['gold', 'coast', 'vineyard'],
#  ['4', 'cépages'],
#  ['vinho', 'branco'],
#  ['the', 'crown', 'jewels'],
#  ['te', 'awa'],
#  ['cabernet', 'family'],
#  ['tramontana'],
#  ['cavallo', 'delle', 'fate'],
#  ['koonunga', 'hill'],
#  ["sharecropper's"],
#  ['east', 'ridge', 'block', 'estate'],
#  ['aszú', '3', 'puttonyos', '-', '500', 'ml'],
#  ['tranquilo'],
#  ["l'instant"],
#  ['cuvée', 'du', 'py'],
#  ['tranquility', 'cabernet', 'sauvignon-tannat'],
#  ['paço', 'dos', 'cunhas', 'de', 'santar', 'nature'],
#  ['weninger', '&', 'gere'],
#  ['arcale'],
#  ['sondraia'],
#  ['small', 'parcels', 'favourite', 'homestead'],
#  ['two', 'creeks', 'vineyards'],
#  ["l'aurore"],
#  ['focus'],
#  ['semi-sweet', 'bianco'],
#  ['passetemps', 'premier', 'cru'],
#  ['el', 'bon', 'homme'],
#  ['de', 'uco', 'gran', 'reserva'],
#  ['rasne'],
#  ['gaintus'],
#  ['fiordiligi'],
#  ['fifth', 'edition'],
#  ['grand', 'marrenon'],
#  ['sentinel', 'northridge', 'vineyard'],
#  ['gala', '2', 'cabernet', 'sauvignon-cabernet', 'franc-merlot'],
#  ['serum'],
#  ['reserva', 'selecció', 'vinyes', 'velles'],
#  ['le', 'grascete'],
#  ['acinatico'],
#  ['yauquen'],
#  ['parenthesis'],
#  ['eremo', 'san', 'quirico'],
#  ['trueheart', 'vineyard'],
#  ['firepeak', 'vineyard'],
#  ['bona', 'vita'],
#  ['preludio', 'barrel', 'select', 'lot', 'n°92'],
#  ['les', 'sorcières'],
#  ['cyprès'],
#  ['winemakers', 'blend'],
#  ['audace', 'riserva'],
#  ['grosso', 'metodo', 'classico'],
#  ['les', 'vieilles', 'vignes', 'de', 'jacques', 'vernay'],
#  ['governo', "all'uso", 'toscano'],
#  ['clos', 'bernarde', 'rosé', 'de', '1ère', 'taille'],
#  ['von', 'unserm', 'trocken'],
#  ['extra', 'dry', '47'],
#  ['breakneck', 'creek'],
#  ['marquès', 'de', 'borba'],
#  ['ensemble'],
#  ['red', 'hen', 'ranch'],
#  ['colinas', 'reserva'],
#  ['dueño', 'de', 'la', 'luna'],
#  ['château', 'de', 'flore'],
#  ['esprit', 'de', 'sarrail'],
#  ['kapnias', 'vineyard', 'zygos'],
#  ['33', 'degrees', 'north', 'gracie', 'hill', 'vineyard,', 'bdx'],
#  ['morine', 'ranch'],
#  ['votre', 'sante'],
#  ['célèbre', 'rosé'],
#  ['year', 'of', 'the', 'dragon'],
#  ['la', 'viña', 'de', 'andres', 'romeo'],
#  ['native', 'goose'],
#  ['terre', 'brûlée'],
#  ["winemaker's", 'reserve', 'estate'],
#  ['gran', 'aracauno'],
#  ["marcy's", 'vineyard'],
#  ['the', 'essence', 'of', 'oregon'],
#  ['elusive', 'queen'],
#  ['minuty', 'prestige'],
#  ['vignes', 'de', '1940'],
#  ['cape', 'winemakers', 'guild', 'hendrik', 'biebouw'],
#  ['fiddlestix', 'vineyard'],
#  ['alte', 'reben', 'pössnitzberg'],
#  ['roi', 'clovis'],
#  ['orient'],
#  ['domaine', 'de', 'la', 'boissoneuse'],
#  ['rosé', 'troteligotte'],
#  ['thomas', 'estate'],
#  ['bricco', 'delle', 'olive'],
#  ['cuvée', 'authentique', 'les', 'clos', 'grand', 'cru'],
#  ['prinz', 'salm', 'spätlese'],
#  ['borgoforte'],
#  ['serrocielo'],
#  ['jubilo'],
#  ['the', 'convict', 'rocky', 'ridge', 'vineyard'],
#  ['the', 'unknown'],
#  ['baba', 'joon'],
#  ['amante'],
#  ['san', 'stunet', '-', 's.', 'stefanetto'],
#  ['doctrina', 'perpetua'],
#  ['spritz', 'and', 'giggles', 'brand', 'cuvée'],
#  ['vigna', 'le', 'coste'],
#  ['hacienda', 'lopez', 'de', 'haro'],
#  ['private', 'reserve'],
#  ['bastion', 'premier', 'cru'],
#  ['cuvée', 'inédite', 'brut', 'blanc', 'de', 'blancs'],
#  ['1865', 'single', 'vineyard'],
#  ['finca', 'vallobera', 'javier', 'san', 'pedro'],
#  ['ried', 'loiserberg'],
#  ['closerie', 'des', 'alisiers', 'domaine', 'fribourg'],
#  ['domaine', 'le', 'cotoyon'],
#  ['vallegrande'],
#  ['and', 'why', 'am', 'i', 'mr.', 'pink?', 'rosé', 'of'],
#  ['gotico'],
#  ["doc's", 'ranch', 'vineyard'],
#  ['puro'],
#  ['grace,', 'hope', '&', 'joy'],
#  ['the', "d'arry's", 'original'],
#  ['nymphéa', 'prestige'],
#  ['la', 'coudraye'],
#  ['la', 'vigna', "dell'angelo"],
#  ['katherine', 'corkrum'],
#  ['canis', 'major'],
#  ['olho', 'de', 'mocho', 'reserva'],
#  ['ried', 'kittel'],
#  ['windfall', 'vineyard'],
#  ['4', 'b'],
#  ['estelle', 'sauvion'],
#  ['le', 'chai', 'des', 'platanes'],
#  ['utopía', 'roble'],
#  ['nik', 'weis', 'selection', 'urban'],
#  ['toko', 'vineyard', 'el', 'corte'],
#  ['terrasses', 'de', 'montmirail'],
#  ['ruby', 'cuvée'],
#  ['palmes', "d'or", 'vintage', 'brut', 'rosé'],
#  ['riserva', 'campore'],
#  ['elegancé'],
#  ['finale'],
#  ['rsrv', 'maison', 'mumm', 'cuvée', '4+5', 'brut'],
#  ['olivet', 'lane'],
#  ['teorama'],
#  ['bourgogne', 'aligoté'],
#  ['mediterranean', 'white'],
#  ['les', 'hauts', 'du', 'tertre'],
#  ['réserve', 'particulière', 'brut'],
#  ['bricco', "dell'uccellone"],
#  ['diane', 'de', 'belgrave'],
#  ['il', 'soller', 'extra', 'dry'],
#  ['maple', 'vineyards'],
#  ['perenzo'],
#  ['campora'],
#  ['piedra', 'negra', 'gran'],
#  ['reserve', 'quintet'],
#  ['bella', 'collina', 'vineyard', 'stiletto'],
#  ['la', 'pilar'],
#  ['bergterrassen', 'federspiel'],
#  ['romantique', 'harmony', 'pilot', 'ridge', 'vineyard', 'estate', 'grown'],
#  ['equus', 'tempranillo-cabernet', 'sauvignon-syrah'],
#  ['heritage', 'collection,', 'six', 'clones'],
#  ['sinfonía', 'tannat-malbec-petit', 'verdot'],
#  ['wente', 'clone', 'old', 'vine'],
#  ['inigo', 'montoya'],
#  ['allegro', 'amabile'],
#  ['harman', 'vineyard'],
#  ['salem', 'vineyard'],
#  ['su', 'reimond'],
#  ['abetina', '2'],
#  ['parris', 'estate', 'reserve'],
#  ['seigneurs', 'de', 'monbazillac'],
#  ['private', 'selection'],
#  ['herrenweg'],
#  ['maucho', 'reserva'],
#  ['ranch', 'reserve'],
#  ['1698'],
#  ['momentos'],
#  ['25th', 'anniversary', 'j', 'cuvée'],
#  ['unionville', 'home', 'single', 'vineyard', 'estate', 'bottled'],
#  ['cuvée', '735', 'brut'],
#  ['egarade', 'brut'],
#  ['9-3-5'],
#  ['balletto', 'ranch'],
#  ['lieu-dit', 'harth', '-', 'cuvée', 'carolin'],
#  ["l'eglantine"],
#  ['torre', 'la', 'moreira'],
#  ['the', 'last', 'ditch'],
#  ['daimon'],
#  ['unbound'],
#  ['vigneto', 'bellavista'],
#  ['munda'],
#  ['traditionelle', 'flaschengärung', 'deutscher', 'sekt', 'extra', 'trocken'],
#  ['five', 'blocks', 'wren', 'and', 'temperance', 'hill'],
#  ['house', 'wine'],
#  ['casual', 'encounters'],
#  ['làvico'],
#  ['krimsekt', 'white', 'collection', 'brut'],
#  ['particular'],
#  ['meandro', 'do', 'vale', 'meão'],
#  ['rive', 'di', 'san', 'floriano', 'brut'],
#  ['premius', 'bordeaux', 'sauvignon'],
#  ['sélection', 'jour', 'de', 'fruit'],
#  ['château', 'de', 'beaucastel'],
#  ['late', 'harvest', 'cluster', 'select', 'reserve'],
#  ['northern', 'state'],
#  ['brut', 'nature', 'reserva', 'de', 'la', 'fami'],
#  ['no.', '239', 'dry'],
#  ['toyon', 'farm'],
#  ['lucumone'],
#  ['lagunilla', 'reserva'],
#  ['uvaggio', 'storico', 'dry'],
#  ['guarda', 'rios', 'branco'],
#  ['morrito', 'estate', 'grown'],
#  ['graševina'],
#  ['origine'],
#  ["l'aura", 'de', 'cambon'],
#  ['terres', 'dorées', 'grille-midi'],
#  ['langenloiser', 'zweigelt'],
#  ['les', 'porets', 'saint-georges', 'premier', 'cru'],
#  ['stickleback', 'red'],
#  ['pont', 'brûlé'],
#  ['generation', 'series', 'cold', 'chalk'],
#  ['viñedo', 'chadwick'],
#  ['the', 'bohan-dillon', 'estate'],
#  ['luminoso'],
#  ['alatus', 'blend'],
#  ['byron', 'vineyard', 'delta'],
#  ["sonnseit'n"],
#  ['into', 'the', 'fog'],
#  ['timeo'],
#  ['mimi'],
#  ['portugieser'],
#  ['rice-spivak', 'vineyard'],
#  ['royal', 'kabinett'],
#  ['10', 'anni', 'riserva'],
#  ['pinot', 'doonier'],
#  ['réserve', 'du', 'propriétaire'],
#  ['meritage', '202'],
#  ['big', 'john', 'big', "john's", 'vineyard', 'vineyard', 'select', 'series'],
#  ['reserve', '-', 'barrel', 'fermented'],
#  ['big', 'bad', 'zin'],
#  ['lailum', 'bianco'],
#  ['yasmin', 'red', 'kosher'],
#  ['michel', 'lynch', 'bio'],
#  ['commendator', 'enrico'],
#  ['organic', 'viticulture'],
#  ['three', 'hills'],
#  ['château', 'cheval', 'noir'],
#  ['brv'],
#  ['elivette'],
#  ['moutier', 'amet'],
#  ['feudo'],
#  ['tsarine', 'premier', 'cru', 'brut'],
#  ['sixgill'],
#  ['unti', 'vineyard', 'old', 'vine'],
#  ['sorante'],
#  ['ramnista', 'single', 'vineyard'],
#  ['vignarè'],
#  ['caligo'],
#  ['pioneer', 'block', '6', 'oh!', 'block'],
#  ['sangre', 'de', 'toro', 'de', 'casta'],
#  ['falleri', 'vineyard'],
#  ['le', 'rosé', 'premier', 'cru', 'brut'],
#  ['sorella'],
#  ['vino', 'de', 'parcela', 'única'],
#  ['chaînes', 'carteaux', 'premier', 'cru'],
#  ['bajancas'],
#  ['château', 'de', 'la', 'deidière'],
#  ['rejoyce'],
#  ['portada', "winemaker's", 'selection'],
#  ['eléve', 'en', 'fûts', 'de', 'chêne'],
#  ['the', 'count'],
#  ['concepción'],
#  ['vita', 'bella'],
#  ['dorn', 'vineyard'],
#  ['black', 'clover'],
#  ['calìo'],
#  ['tenuta', 'valleselle', 'aurum'],
#  ['valamasca'],
#  ['wineck-schlossberg', 'grand', 'cru'],
#  ['privat', 'gran', 'reserva', 'brut', 'nature'],
#  ["l'oie", 'de', 'périgord'],
#  ['fiori',
#   'delle',
#   'stelle',
#   'ice',
#   'wine',
#   'block',
#   '1',
#   'vidal',
#   'blanc-golden',
#   'muscat-marechal',
#   'foch'],
#  ['fina', 'reserva', 'ensamblaje', 'sauvignon', 'blanc-chardonnay-viognier'],
#  ['cape', 'winemakers', 'guild', 'ghost', 'corner', 'cwg'],
#  ['cuvee', 'rae', 'lee', 'avonlea'],
#  ['moelleux'],
#  ['the', "king's", 'fury'],
#  ['erdener', 'prälat', 'auslese', 'goldkapsel'],
#  ['elwetritsche'],
#  ['dona', 'georgina'],
#  ['navigato', 'family', 'selection'],
#  ['in', 'the', 'hills', 'estate', 'foothills', 'in', 'the', 'sun', 'vineyard'],
#  ['yasmin', 'red'],
#  ['terre', 'del', 'vulcano'],
#  ...]

# %%
# # Add stop words to sklearn stopwrods text
# stop_words_sk = text.ENGLISH_STOP_WORDS.union(winery_list).union(varietal_list).union(region1_list)\
# .union(region2_list).union(designation_list)

# %%
stop_words_sk = text.ENGLISH_STOP_WORDS.union(designation_list)

# %%
new_stop_words = []
new_stop_words.append(text.ENGLISH_STOP_WORDS)

# %%
stop_words_sk
# Out:
# frozenset({'rhinefarm vineyard',
#            'dineen vineyard',
#            'outer limits',
#            'light horse',
#            'fighting bulls',
#            'la grande cuvée',
#            'paso doble malbec-corvina',
#            'flò',
#            'morgado da canita',
#            'les galets single vineyard',
#            'petit monts premier cru',
#            'quartilho branco',
#            'cepas centenarias',
#            'bacchus',
#            'el fanio',
#            'selleck vineyard',
#            'clone 115 indigène estate',
#            'kremser wachtberg reserve',
#            'fortulla',
#            'monte foscarino',
#            "verna's vineyard",
#            'dolce bianco',
#            'vz van zellers',
#            'california',
#            "chevalier d'anthelme",
#            'altar',
#            'the cynic',
#            'sceales vineyard',
#            'satrapezo',
#            'estate stonessence in the rocks vineyard',
#            'francis reserve white',
#            'monte da peceguina tinto',
#            'domaine de grand croix',
#            'domaine du manay',
#            'lo scuro',
#            'spellonu red',
#            'ciampaign vieris',
#            'rock lake',
#            'strada di guia, 109 extra dry',
#            'duas quintas reserva',
#            'passione passito cason brusà',
#            'evolution big time',
#            'gilt',
#            'russian camp',
#            'semi dry - estate bottled',
#            'le bois martin',
#            'the tri-centenary',
#            'vendimia seleccionada blanco',
#            'select',
#            'd block reserve',
#            'mount hermon',
#            "matthew's block",
#            'san giovanni della sala',
#            'flaccianello',
#            'castello',
#            'la piazza alta',
#            'louvau vineyard old vines',
#            'cape roca fisherman',
#            'sonoma county selection',
#            'estate grown rosato di',
#            'baranoff vineyard estate grown',
#            '20 yr. baco imperial amontillado',
#            'made with organic grapes',
#            'catarina',
#            'cava brut rosé',
#            'bois meyney du château nardou',
#            'quinta do encontro q do e',
#            'punto final mlb',
#            'les complices',
#            'les bartavelles',
#            'clifton vineyard',
#            'dauntless',
#            'trabener würzgarten kabinett trocken',
#            'rieflé bihl',
#            'audaz branco',
#            'scharzhoferger spätlese',
#            'rattlesnake hill',
#            'arió extra dry',
#            'grapes organically grown',
#            'vigna della madonnina riserva',
#            'légende des toques',
#            'bishop creek vineyard',
#            'the cigar menzies vineyard',
#            'torcolato',
#            'duetorri',
#            'au dessus de la loi andlau',
#            'reserve bingham vineyard',
#            'cellar select',
#            'kiara private reserve',
#            'selezione antonio chiorri',
#            'the enchantress chardonnay french creek vineyard',
#            'kick ranch',
#            'bunker hill vineyard',
#            'cedrus le blanc',
#            'vallocaia riserva',
#            'folly',
#            '30 years old white',
#            'sori paolin',
#            'élite oloroso',
#            'korte ranch',
#            'lawrence vineyard le paon',
#            'altos de losada viñedos viejos pequeñas parcelas',
#            'jp azeitão',
#            'tenute sirignano',
#            'estate grown proprietary red blend',
#            'santufili',
#            'annadel gap vineyard estate',
#            'eisrébe',
#            'löwengang',
#            'les princes abbés',
#            'private bin',
#            'bossona riserva',
#            'donna marzia',
#            'calcaire',
#            'light madeira',
#            'vintage reserve',
#            'cuvée garance',
#            'morse vineyards',
#            "yesterday's song",
#            'pizzella',
#            'tonì',
#            'silverwood vineyard mountain grown',
#            'da vinci',
#            'osé rosé brut',
#            'macedon',
#            'doro nature',
#            'system',
#            'cole ranch',
#            'bernier zinyard',
#            'grateful red',
#            'tagus creek chardonnay-fernão pires',
#            'boxwood',
#            'heritage clones',
#            'tierra roja',
#            "l'entente blanc",
#            'anaperenna',
#            'elemental',
#            'venus',
#            'monplaisir',
#            "cà de' rocchi",
#            'patriarche',
#            'alwenn',
#            "old vine dina's vineyard",
#            'woodruff family vineyard',
#            'zinnkoepflé grand cru',
#            'de nit',
#            'poggio alla pietra brunello di sonoma estate grown',
#            "vigna 'ngena",
#            'pena do lobo',
#            'lounge',
#            "villa d'ariane",
#            'upland',
#            'château reserve',
#            'la bête noire',
#            'principia reserve',
#            "ellie's old vine",
#            'monastrell / petit verdot',
#            '6025',
#            'szent tamás betsek vineyards',
#            'the expedition canoe ridge estate vineyard',
#            "the fusilier proprietor's reserve",
#            'malterdinger bienenberg r gg erste lage',
#            'coyam los robles estate organic',
#            'sweet red table wine',
#            'robert willis reserve',
#            'torre muga',
#            'ma roat',
#            'semi seco',
#            'casa nocera',
#            'viña real reserva',
#            'volume three',
#            'san rocco',
#            'vigna giaia',
#            'sarmassa',
#            'sorangela',
#            'georgian valleys alazani valley',
#            'giersberger rosé',
#            'sergio extra dry',
#            'viridescens',
#            'panesa fino',
#            'whom',
#            'el albar lurton barricas',
#            'odyssea',
#            'inspiration vineyard magnolia series',
#            'artist series #7 red wine',
#            'monster block',
#            'margus margi',
#            "summation vintner's reserve",
#            'frederick brut',
#            "judge's reserve",
#            'levity',
#            'single vineyard plot: malva',
#            'salvestrin estate vineyard',
#            'three degrees',
#            'stellar vineyard',
#            'reina ana gran reserva',
#            'beginning',
#            'viña rubican crianza',
#            'armi vineyard',
#            'modello delle venezie',
#            'ensemble blanc',
#            'quinta do cachão',
#            'reserva la consulta vineyard',
#            'ananto',
#            'aah',
#            'cuvee trudi cuvee #10 rosé',
#            'tinaquaic vineyard',
#            'en chamberlin el jefe',
#            'bianco di ceparano',
#            "cape winemakers guild daisy's turn shiraz-cabernet sauvignon-mourvèdre",
#            "courtney's",
#            'marina espumante f° espumoso de fermentación natural',
#            'firehouse vineyard',
#            'gran reserva edición limitada',
#            'goldrock ridge vineyard',
#            'bombshell red',
#            'anada',
#            'marriage',
#            'merlot - cabernet sauvignon - shiraz',
#            'padrone',
#            'gravity',
#            'la chaudouillonne',
#            'javier asensio reserva',
#            'clon de la familia',
#            'buena tierra vineyard',
#            'vale de cavalos',
#            'divinity late harvest',
#            'brave & maiden vineyard',
#            'the surrealist',
#            'coure di vigne',
#            "sawyer lindquist vineyard sonnie's",
#            'windrow vineyards windrow red',
#            'sarah block swan song reserve',
#            'cutthroat red',
#            'san claudio ii',
#            'tridentum brut rosé',
#            'quercetonda',
#            'spellbinding',
#            "l'erta",
#            'sorì bric camparo',
#            'no. 77',
#            'joven',
#            'les plantés',
#            'bella vigna vineyard',
#            'fairbairn ranch',
#            'domaine la soufrandière',
#            'dolce',
#            'betsy vineyard',
#            'eichberger',
#            "doctor's vineyard",
#            'rioja bordón reserva',
#            "catie's corner cuvée orange",
#            "verna's estate",
#            'bastardo-merlot',
#            'baron de chirel reserva',
#            'eroica ice wine',
#            'no 46',
#            'fitz extra trocken sekt',
#            "tyche's mustard single vineyard",
#            'buzz',
#            'qm',
#            'i fondatori riserva',
#            'ascent',
#            'poggio etrusco',
#            'three vineyards',
#            'dakishvili family vineyard',
#            'raso de larrainzar',
#            'm',
#            'gravelstone',
#            "rocche dell'annunziata",
#            'la citadelle',
#            'terras do grifo selected harvest',
#            'pian di nova',
#            'opere trevigiane millesimato',
#            'terraces',
#            "primo's hill, estate grown",
#            'médeville collection',
#            "textures'de pedra blanc de negres",
#            'savagnin sous voile',
#            'guidici vineyard',
#            'viento vineyard',
#            'plexus frisante rosé',
#            'danseur',
#            'brut x',
#            'georges iii vineyard',
#            'pato frio grand escolha',
#            'traditionale',
#            'bank three creek vineyard',
#            'clasico',
#            'if six was nine reserve',
#            'block selection reserve block n.13',
#            'le puy rolland',
#            'rive di colbertaldo vigneto giardino asciutto',
#            'water witch',
#            "cali's cuvée",
#            'r reserve',
#            'touriga nacional-merlot',
#            'amantis',
#            'morellone',
#            'arcurìa rosso',
#            'castillo ygay gran reserva especial',
#            'domaine des hospices de belleville',
#            'neirane',
#            'cuvée paparazzi',
#            'fementado en barrica',
#            'mor',
#            "charlotte's home estate",
#            'cuvée royale brut rosé',
#            'coast view vineyard',
#            'dalva reserva',
#            "on l'appelle",
#            'el preciado gran reserva',
#            "sant'anna",
#            'trittenheimer apotheke beerenauslese',
#            'ourselves',
#            'quinta da vargellas vintage',
#            'maria mora',
#            'taglsteiner',
#            'muros antigos escolha',
#            'lena di mezzo',
#            'les grès',
#            'collines de granit',
#            'la poja',
#            'cuvée eva',
#            'regan vineyard orange wine',
#            'passion',
#            'black bubbles sparkling',
#            'phinny hill',
#            'quattuor blanc de quatre blancs brut',
#            'goldtröpfchen spätlese',
#            'gebling kellerterrassen reserve',
#            'caleno oro',
#            'château tour blanche',
#            '1909',
#            'villa prandone navicchio',
#            'terre originelle',
#            'ausstich',
#            'crios rosé of malbec',
#            'la baldea',
#            'murta',
#            'nierstein trocken',
#            'vineyard block 4sb20',
#            "julia's vineyard",
#            'i puri',
#            'poggio alle mura',
#            'espiga',
#            'estate block k1',
#            'lot 360',
#            'credas rive di farra di soligo brut',
#            'lost vineyard',
#            'medium',
#            'corte c',
#            'domaine les hautes roches',
#            'detour',
#            "d'autor",
#            'champ salomon',
#            'ducceto',
#            'rosé brut metodo classico',
#            'cuvée elena',
#            'villa marchesi',
#            'further',
#            'violet',
#            'jassarte',
#            'old vine reserva',
#            "garrett's vineyard estate",
#            'heringer estate vineyard',
#            'chenoweth ranch',
#            'chaos theory',
#            'altenasso',
#            'raptor private reserve',
#            'aux cras',
#            'once',
#            'grand baron',
#            'corte b',
#            'quass',
#            'ole',
#            'olivia vineyard',
#            'michel forget premier cru brut',
#            'cuvée larsinos',
#            'dona isabel juliana',
#            'coast grade vineyard',
#            'grambeira tinto',
#            'epinette',
#            'thomas schmitt private collection estate bottled spätlese',
#            'royal cuvee brut',
#            'fumé blanc dry',
#            'gold mine ranch',
#            'champ des fleurs',
#            'seven springs vineyard',
#            'de sangre',
#            "colombelle l'original blanc",
#            'manu',
#            'oloroso library reserve',
#            "ca' rosa",
#            'riot girl',
#            'lightning',
#            'rouge noir',
#            'villa blanche',
#            'f/red',
#            'mistral red',
#            'miamba',
#            'i unacepa',
#            'old vines reserve',
#            'rosé de saignée premier cru brut',
#            'natura',
#            'memòro',
#            'exclusiv',
#            'la perrière',
#            'amaro',
#            'vieilles vignes de cramant grand cru',
#            'puer apuliae',
#            'dos fincas',
#            'loibner loibenberg smaragd',
#            'le photographe',
#            'artz vineyard',
#            'been',
#            'mantsch',
#            'reservado',
#            '3rd generation',
#            'rosso',
#            'le phare cabernet sauvignon',
#            'sélection belles années blanc de blancs brut',
#            'palisades',
#            'vitiano',
#            'alder ridge vineyard rosé',
#            'tasmin',
#            'sagemoor',
#            'la fleur du barril',
#            'ramón roqueta',
#            '1922',
#            'beautiful things',
#            "f'oz",
#            'le fetrau',
#            'outeiro',
#            'georgetown divide',
#            'm. vigna',
#            'big tree block',
#            'big river ranch vineyard series',
#            'the cypher',
#            'totem ridge',
#            "l'etoile de begude",
#            'passagem late bottled vintage',
#            'clos des poruzots premier cru',
#            'eight barrels',
#            "icon d'azamor",
#            'passadouro porto tawny reserve',
#            'vico riviera',
#            'bleu de mer',
#            'beet red',
#            'slippery slope vineyard',
#            'castello di nipozzano mormoreto',
#            'chamán gran reserva',
#            'brumaire',
#            'jacques sans souci',
#            'torre de menagem',
#            'il passo',
#            'cru perdu',
#            'berrichon',
#            '3 puttonyos aszú',
#            'white hill',
#            'los lingues vineyard',
#            'thérèse vineyards',
#            'felseneck walhausen spätlese grosse lage',
#            'ried hochberg',
#            'reserva selección de 198 barricas',
#            'malbec-merlot-cabernet sauvignon',
#            "jane's vineyard dijon clone 777",
#            'chardonnay premier cru brut',
#            'capitello',
#            'elusive',
#            "l'andéol",
#            'grilos',
#            'can feixes blanc selecciò',
#            'treehouse cabernet sauvignon-merlot-cabernet franc',
#            'fleurs de savagnin',
#            'corte del pozzo',
#            'vigno old vines dry farmed',
#            'sur la mer',
#            "l'esprit de marius sangouard",
#            'orbus',
#            'elevation old vine',
#            'single vineyard series lewis vineyard',
#            'estate vineyards white',
#            'belezos crianza',
#            'undhof auslese',
#            'single frementation',
#            'selecção cabernet sauvignon-touriga nacional',
#            'le connétable',
#            'les galets dorés',
#            'der königsberg',
#            'revelation',
#            'babu',
#            'orthogneiss sur lie',
#            'becquer',
#            'cicogna',
#            "rocche dell'annunziata riserva",
#            'tinto roa reserva',
#            'montepulciano-sangiovese',
#            'grand clos',
#            'aristeo',
#            'les sizies premier cru',
#            'overture',
#            'leras vineyard',
#            'réserve grand cru brut',
#            'huntington',
#            'riverbend vineyard tribute',
#            'motley cock',
#            'identity crisis',
#            'grand ciel vineyard',
#            'les lavières premier cru',
#            'gentil de katz',
#            'tsarine millésime brut',
#            'esprit de tablas blanc',
#            'folin vineyard',
#            'sotirio',
#            'coccineous estate',
#            'three corner jack shiraz-cabernet-merlot',
#            'rolleri cuvee',
#            'mckinley springs vineyard',
#            'clay wheels',
#            'exception blanche brut',
#            'herdade do peso colheita',
#            'white hawk',
#            'erminia de meo',
#            'berncasteler doctor kabinett gold cap',
#            'templários colheita seleccionada',
#            'sls single blend',
#            'serene rose of tempranillo',
#            'armando',
#            'sorhô',
#            'graacher himmelreich auslese goldkap',
#            'campo prognài',
#            'réserve des cleons',
#            'regaleali le rose',
#            'chenin blanc ice wine',
#            'domaine chenevières',
#            "vintner's cuvee xxi",
#            'dutton palms vineyard',
#            'jme selección',
#            'tentation by renucci',
#            'silvaspoons vineyard',
#            'reserva lo mejor illusión',
#            'gsmv',
#            'goldberg alte reben',
#            'torre di luna',
#            'bergera pezzole',
#            'the lost watch',
#            'domaine des deux roches plénitude e bonté',
#            'cadò',
#            'classique',
#            'freedom hill vineyard dijon clone',
#            'enterprise vineyard',
#            'chatenay',
#            'domaine de reuilly les fossiles',
#            'königsberg',
#            'de mar plavac',
#            'dario estate',
#            'château léret monpezat',
#            'valle zangão',
#            'randolph reserve',
#            'la quintessence',
#            'avonlea',
#            'duemiladieci bianco metodo classico',
#            'grand estates gold limited release',
#            'juliard vineyard',
#            'solesce',
#            'corona de aragón',
#            'reserve maple',
#            'ramal vineyard',
#            'vignes de 1939',
#            'ceuso',
#            'u cantu',
#            'vinho',
#            'opera 02',
#            'ockfener bockstein kabinett erste lage',
#            'cuvée st clément',
#            'strayts',
#            'pourriture noble',
#            "l'ange et luce",
#            'late harvest estate bottled',
#            'colson canyon vineyard clone 877',
#            'private selection branco',
#            'montornello',
#            '16 crows cuvée',
#            'serious',
#            'ronco dei ciliegi',
#            'renner',
#            'thomas road',
#            'cuvée du golfe de saint-tropez',
#            '6',
#            'le roi des pierres',
#            'cat amongst the pigeons nine lives',
#            'tirso',
#            'tenuta lena di mezzo',
#            'dry rosé of',
#            'lot #34 dry farmed old vine',
#            'lineage the chairman series',
#            'match',
#            'la fleur ribeyrolles',
#            'grande mélange',
#            'dry estate vineyards',
#            "feuerheerd's 10-year-old tawny",
#            'tinta miúda',
#            'zinnkoepfle grand cru',
#            'signature selection',
#            'estate selection',
#            'anno zero extra dry',
#            'va viña aljibes',
#            'caligo essència sweet white wine',
#            'riverside crossing',
#            'marquis philips s2',
#            'arbor creek vineyard',
#            'spring creek',
#            'angimbé',
#            'lower east',
#            'casal garcia medium dry',
#            'johannisberg hölle gg',
#            'bric du luv',
#            'native yeast',
#            'giusti ranch estate',
#            'julian madrid reserva',
#            'single organic vineyard',
#            'vigneto rafaèl',
#            'unánime',
#            'michaud vineyard',
#            "hailey's block",
#            'domaine de la garenne',
#            'diavolo',
#            'henoba',
#            'riva rocca',
#            'cuma made with organic grapes',
#            'pago negralada',
#            'zwischen den seen nummer 3 kollektion l08a',
#            'les hauts de sainte marie',
#            'beyond the clouds',
#            'two acre villa andriana vineyard estate',
#            'acquilae',
#            "la croix d'argon",
#            'bdp y',
#            'chiaretto',
#            'rock lake red',
#            'cobblestone vineyard reserve',
#            'casal garcia sweet',
#            'laplace',
#            'damaris reserve',
#            'la garrigue',
#            'jayson',
#            'les clos',
#            'gelbling',
#            'les sources',
#            'cuvee cassidy',
#            'innere bergen',
#            'norma jean',
#            'quinta do cardo reserva branco',
#            'ours',
#            'silveredition passione',
#            'margo',
#            'ridge block single vineyard selection',
#            'brut carte noire',
#            'les moriers',
#            'la noblaie rouge',
#            'clérotstein',
#            'les brûlés',
#            "l'universelle brut",
#            'cuvée des moines brut',
#            'marquês de marialva reserva',
#            'terzetto',
#            'ten degrees vineyard',
#            'lágrima',
#            'tenuta di altavilla',
#            '73% washington/27% oregon',
#            'terroir series finca coletto single vineyard',
#            'vs reserva',
#            'abbaye de morgeot premier cru',
#            'conde de vimioso extra bruto',
#            'le rosé de julie',
#            'late harvest botrytised grapes',
#            'grand cru millésimé blanc de blancs brut',
#            'ardal gran reserva selección especial',
#            'brique prestige',
#            'essence saten',
#            'perle',
#            'envie de joÿ',
#            'leonardini vyd',
#            'scharlachberg bingen auslese',
#            'dolç mataró organic sweet',
#            'upland vineyard gravière g.s.m.',
#            're',
#            'omaggio a gino friedmann',
#            "poggio all'oro riserva",
#            'mirabelle brut',
#            "tour'ga franc reserve",
#            't noble late harvest',
#            'clos prieur premier cru',
#            'yates conwill vineyard',
#            'loire valley demi-sec',
#            'francis coppola diamond collection black label claret',
#            'kretikos',
#            'célèbre',
#            'interra rosso',
#            'palestra branco',
#            'château grand chemin monplaisir',
#            "l'arzelle",
#            'barricato 40',
#            'escaliers stairs',
#            'qp',
#            'le canon du marechal',
#            'quinta da aveleda estate bottled loureiro-alvarinho',
#            'purple by lagrezette',
#            'tolos',
#            'kittl',
#            'johann federspiel',
#            'petit enira',
#            'whereafter',
#            'herú',
#            'marnà',
#            'campo lindo fresh',
#            'solano',
#            'don nelson gran reserva edición limitada',
#            'the blue note',
#            'elerding six prong vineyard',
#            'fifty tons',
#            'rüdesheim berg roseneck trocken erstes gewächs',
#            'sofos the wise one moschofilero-chardonnay',
#            'dionysus vineyard',
#            'château nozières',
#            'java by chiroulet',
#            'bench',
#            'les meyans elégance',
#            'le millésimé brut',
#            'las cruces single vineyard old bush vines',
#            'les cerisiers vieilles vignes',
#            'reserve mernet',
#            "koos-koos-kia colter's creek vineyard",
#            'la flatteuse brut rosé',
#            'exception',
#            'unfined and unfiltered',
#            'garnacha fusión',
#            'dauphiné',
#            'twelve barrels',
#            'siebert ranch',
#            'bernkasteler badstube  kabinett',
#            'la roggia',
#            'round mountain volcano',
#            'retsina of attica',
#            'dry creek mountain vineyard',
#            'hoya de cadenas reserva',
#            'peninsula de lisboa',
#            'klin',
#            'esporão colheita',
#            'a vampa',
#            'torrediluna',
#            'cuvée château',
#            'roadside red',
#            "vigneti sant'helena",
#            'château des erles',
#            'ravat 51',
#            'handverlesen',
#            'viña borgia',
#            'château argadens',
#            'tourmaline',
#            'côtes de paso blanc',
#            'amerique',
#            'porca de murça reserva',
#            'despina',
#            'private reserve estate grown',
#            'pinot gris',
#            'five roses',
#            'les vignes de joanny',
#            'v3',
#            'brauneberger  kabinett trocken',
#            'finca las palmas gran reserva',
#            '1769',
#            'campodipietra',
#            'golden reserve',
#            'bicentennial commemorative bottling',
#            'the y series limited release rosé',
#            'taylor lane vineyard',
#            'bon vallon',
#            'hochheimer kirchenstück beerenauslese',
#            'cuvée prédilection brut',
#            'stained tooth',
#            'herdade do peso trinca bolotas',
#            'domaine de la croix bouqure',
#            'suri di mu',
#            'wine for pizza',
#            'tonada torrontés-chardonnay',
#            'the big game',
#            'interra bianco',
#            'nonno rico oriolo riserva',
#            'epenots premier cru',
#            'unoaked estate',
#            'principe guerriero',
#            'vivio vineyard',
#            'le zere',
#            'saitone vineyard olivet bench',
#            'calidonia',
#            'réserve millésimée brut',
#            'squarcialupi riserva',
#            'herdade de são miguel escolha dos enólogos',
#            'lopez ranch old vine',
#            'mama mia estate grown',
#            'piesporter goldtröpfchen gg trocken',
#            'chenin avec chêne wooded',
#            'le chevalier de sterimberg',
#            'touch of oak',
#            'grand va',
#            'spirit of pinot noir',
#            'carreras ranch',
#            'vignes blanches',
#            'quater',
#            'estate reserve blend',
#            'sangioveto',
#            'sélection vieilles vignes sur lie',
#            'il tabarro',
#            'toques et clochers océanique',
#            'bk',
#            'fordbidden',
#            'charbonneau',
#            'terra summa',
#            'côt red wine dineen vineyard',
#            'studi fraedane',
#            'vinya les sorts',
#            'cuvée valérie',
#            'oriana',
#            'símbolo',
#            'domaine hamelin marly',
#            'a modern',
#            'quest by cauhapé',
#            'domaine du pavillon clos des maréchaudes',
#            'benuara',
#            'album lua cheia em vinhas velhas',
#            'bestué de otto bestué',
#            'sneaky',
#            'château de fontaine-audon',
#            'special reserve master of port',
#            "château de la mulonnière à la faveur d'automne",
#            'opale demi-sec',
#            'kreuznacher kabinett',
#            'cuvée caractères',
#            'martinet bru',
#            'domaine de saint pierre',
#            'nine mile red table wine',
#            'renaissance vendanges tardives',
#            'randersackerer pfülben gg trocken',
#            'block 137',
#            'brut perlé',
#            'follies',
#            "chatte d'avignon",
#            'quinta de pancas grande escolha',
#            'vin de paille',
#            'archè',
#            'les charmes dessus premier cru',
#            'vineis',
#            'lindes de san vincente',
#            'zwirch reserve',
#            'aramis',
#            'pickberry vineyard reserve',
#            'essentija',
#            'gaia made with organic grapes',
#            'night owl',
#            'tre saggi',
#            'món clàssic',
#            'francos reserva',
#            'mouton cadet réserve',
#            'viñedo no. 9',
#            'vieilles vignes domaine des chazelles',
#            'vigna santa riserva',
#            'alphabet wines',
#            'grande cuvée blanc de blancs brut',
#            'anninger',
#            'cuvée vintage brut',
#            'the heritage collection six clones',
#            'sigma syrache',
#            'oso grande',
#            'san remo',
#            'aux clous premier cru',
#            'bramare zingaretti vineyard',
#            'barron-wahl vineyard',
#            'vigneto monachiara',
#            'assunto riserva',
#            'estate grand reserve',
#            'one last syrah',
#            'les pierres chaudes',
#            'river junction',
#            'agioritikos regional dry white wine',
#            'dindarello',
#            'stillwater creek vineyard the wanted',
#            'clos de chênes premier cru',
#            'rio vista vineyard',
#            'crisp',
#            'davis vineyard dry',
#            'herea',
#            'cenerentola',
#            'vers châne',
#            'santavenere',
#            'single vineyard series clifton hill vineyard',
#            "archer's edge estate",
#            'alma semillon-viognier-pinot gris',
#            'redemption zin',
#            'coeur de cuvée premier cru brut',
#            'yacochuya',
#            'syrah du soleil',
#            'estate malbec',
#            'erdener prälat auslese',
#            'saggio',
#            'gerstein special edition',
#            'francis coppola diamond collection gold label',
#            'san floriano vineyard',
#            'mas elena merlot-cabernet franc-cabernet sauvignon',
#            'some poets',
#            'bucher vineyard three sixty',
#            'edna ranch vineyard',
#            'ravera di monforte',
#            'médallion',
#            "rodney's vineyard",
#            'cuvée françois signature',
#            'memsie shiraz-cabernet sauvignon-malbec',
#            'he',
#            'brut vintage',
#            'cantina di colognola acinatico 500ml',
#            'bollenberg',
#            '20 years old tawny',
#            'elevé en fût de chêne',
#            'cuvée q.v. paul brut',
#            'finley road vineyard',
#            'empreinte rouge',
#            'grechons premier cru',
#            'brut quvée 15',
#            'ried renner',
#            'bernau block',
#            'château du cléray vallet',
#            'grande reserve',
#            'treborce reserve',
#            'blackberry block',
#            'lp brut',
#            'ghielmetti estate vineyard',
#            "château de l'echarderie",
#            'rüdesheim kabinett feinherb',
#            'la casita',
#            'tavernello',
#            'monte carbonare',
#            'pioneer block 16 awatere',
#            'no 2 de saint-martin',
#            'blauschiefer',
#            '1620',
#            'brusco dei barbi',
#            'sernauberg erste lage',
#            'sauvignon blonde',
#            'ava',
#            'intrinity',
#            'calpena extra dry',
#            'campo di mezzo',
#            'caiado tinto',
#            'the reserve rosé of',
#            "la chapelle d'ausone",
#            'cuvée hors classe les ménétrières',
#            'tradición',
#            "pauline's vineyard grenache",
#            'ozv',
#            'rued clone',
#            'jkii estate vineyard',
#            'sentimental blonde',
#            'solamini et amicis passito',
#            'castello fonterutoli',
#            'santos da casa reserva sem barrica unoaked',
#            'final',
#            'talitha cumi bloc in prayer rock vineyards',
#            "ltd livin' the dream",
#            'alsace dream',
#            'lot 501',
#            'sodamagri',
#            'almazan',
#            'hedone rosso',
#            'byington vineyard',
#            'ororosso dosaggio zero',
#            'meia lua',
#            "les vignes d'elisa",
#            'la viminière',
#            'abbott claim vineyard',
#            'domaine danielle laurent',
#            'red heaven vineyard reserve',
#            'luvisi vineyard',
#            'terrasses du bouscadel',
#            'rho',
#            'red label aszú 5 puttonyos - 500 ml',
#            'first spoke patrician verona vineyard',
#            'floodgate',
#            'angel hawk',
#            'est rosa',
#            'le cicale',
#            'single vineyard kayoumi',
#            'blauer schulen',
#            'manzana vineyard',
#            'deyo',
#            'virga',
#            "proprietor's reserve tudor hills vineyard",
#            'barra family vineyards',
#            'sullivan',
#            'estate bottled vinho tinto',
#            ...})

# %%
#stop_words_sk

# %% [markdown]
# # CVectorizer to gensim LDA

# %%
# CountVectorizer
cv1 = CountVectorizer(ngram_range=(1, 2),  
                                   stop_words=stop_words_sk, token_pattern="\\b[a-z][a-z]+\\b")

# %%
cv1.fit(df.description)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 2), preprocessor=None,
#                 stop_words=frozenset({nan, '#19 phantom limb belmont vineyard',
#                                       '#50 mon chou', '#socialsecret', '%@#$!',
#                                       '&', "'61 rosé", "'a rina",
#                                       "'blend 105' red wi...
#                                       "'na vota", "'p'", "'s'", "'unfiltered'",
#                                       "'vie!'", '(+)', '(steen)', '*%#&@!',
#                                       '+ brut metodo classico',
#                                       '+ summa  varietals syrah-cabernet '
#                                       'sauvignon-petit verdot',
#                                       '+7', '0 degree dry',
#                                       '0 degrees of riesling dry', '0,618',
#                                       '0.5 brix', '006 riverside estate', '01',
#                                       '075 carati', '075 carati brut',
#                                       '075 carati extra dry', ...}),
#                 strip_accents=None, token_pattern='\\b[a-z][a-z]+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
# Create the term-document matrix
# Transpose it so the terms are the rows
doc_word = cv1.transform(df.description).transpose()

# %%
doc_word
# Out:
# <699388x119988 sparse matrix of type '<class 'numpy.int64'>'
# 	with 4689911 stored elements in Compressed Sparse Column format>

# %%
doc_word.shape
# Out:
# (699388, 119988)

# %%
# Convert sparse matrix of counts to a gensim corpus
corpus = matutils.Sparse2Corpus(doc_word)

# %%
corpus

# %%
id2word = dict((v, k) for k, v in cv1.vocabulary_.items())
# order is actually word to id

# %%
len(id2word)
# Out:
# 699388

# %%
lda = models.LdaModel(corpus=corpus, num_topics=10, id2word=id2word, passes=10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-7789c4df8d6a> in <module>
# ----> 1 lda = models.LdaModel(corpus=corpus, num_topics=10, id2word=id2word, passes=10)
#
# /anaconda3/envs/metis/lib/python3.7/site-packages/gensim/models/ldamodel.py in __init__(self, corpus, num_topics, id2word, distributed, chunksize, passes, update_every, alpha, eta, decay, offset, eval_every, iterations, gamma_threshold, minimum_probability, random_state, ns_conf, minimum_phi_value, per_word_topics, callbacks, dtype)
#     517         if corpus is not None:
#     518             use_numpy = self.dispatcher is not None
# --> 519             self.update(corpus, chunks_as_numpy=use_numpy)
#     520
#     521     def init_dir_prior(self, prior, name):
#
# /anaconda3/envs/metis/lib/python3.7/site-packages/gensim/models/ldamodel.py in update(self, corpus, chunksize, decay, offset, passes, update_every, eval_every, iterations, gamma_threshold, chunks_as_numpy)
#     978                         pass_, chunk_no * chunksize + len(chunk), lencorpus
#     979                     )
# --> 980                     gammat = self.do_estep(chunk, other)
#     981
#     982                     if self.optimize_alpha:
#
# /anaconda3/envs/metis/lib/python3.7/site-packages/gensim/models/ldamodel.py in do_estep(self, chunk, state)
#     740         if state is None:
#     741             state = self.state
# --> 742         gamma, sstats = self.inference(chunk, collect_sstats=True)
#     743         state.sstats += sstats
#     744         state.numdocs += gamma.shape[0]  # avoids calling len(chunk) on a generator
#
# /anaconda3/envs/metis/lib/python3.7/site-packages/gensim/models/ldamodel.py in inference(self, chunk, collect_sstats)
#     694                 Elogthetad = dirichlet_expectation(gammad)
#     695                 expElogthetad = np.exp(Elogthetad)
# --> 696                 phinorm = np.dot(expElogthetad, expElogbetad) + epsilon
#     697                 # If gamma hasn't changed much, we're done.
#     698                 meanchange = mean_absolute_difference(gammad, lastgamma)
#
# KeyboardInterrupt:

# %%
lda.print_topics()
